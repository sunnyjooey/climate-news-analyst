# %% [markdown]
# # An exploration on topic modeling.
# # Searching through the LDA hyperparameters to find topics that are meaningful.

# %%
#Special module written for this class
import lucem_illud #pip install -U git+git://github.com/Computational-Content-Analysis-2018/lucem_illud.git

#These are all for the cluster detection
import sklearn
import sklearn.feature_extraction.text
import sklearn.pipeline
import sklearn.preprocessing
import sklearn.datasets
import sklearn.cluster
import sklearn.decomposition
import sklearn.metrics

import scipy #For hierarchical clustering and some visuals
import gensim#For topic modeling
import nltk #the Natural Language Toolkit
import requests #For downloading our datasets
import numpy as np #for arrays
import pandas #gives us DataFrames
import matplotlib.pyplot as plt #For graphics
import matplotlib.cm #Still for graphics
import seaborn as sns #Makes the graphics look nicer

import pandas as pd
import itertools
import json

# %matplotlib inline

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
news_df1 = pd.read_pickle('../news_df_norm1.pkl')
news_df2 = pd.read_pickle('../news_df_norm2.pkl')
news_df = pd.concat([news_df1, news_df2])

# %%
def dropMissing(wordLst, vocab):
    return [w for w in wordLst if w in vocab]

# %%
def topic_loop(df, stop_words, num_topics, max_dfs, max_features, norm_type, alphas, etas, random_number=None):
    """
    Outputs top topics words according throughout all the hyperparameter combinations.
    Params:
        df: Dataframe with text to be analyzed. Requires column named "normalized tokens" with text 
            as tokens that have been stemmed and lemmatized.
        random_number: Seed for the LdaModel. Default None will give out a different model every 
            time for the same parameter combination.
        All other parameters are lists of that param name to be passed to gensim.LdaModel
    """
    for num in num_topics:
        for d in max_dfs:
            for f in max_features:

                TFVectorizer = sklearn.feature_extraction.text.TfidfVectorizer(max_df=d, min_df=20, 
                    max_features=f, stop_words=stop_words)
                TFVects = TFVectorizer.fit_transform(df['text'])
                
                for norm in norm_type:
                    # drop
                    reduced_token_str = 'reduced_tokens_' + norm + '_' + str(num) + '_' + str(d) + '_' + str(f)
                    norm_col = 'normalized_tokens' + norm
                    df[reduced_token_str] = df[norm_col].apply(
                        lambda x: dropMissing(x, TFVectorizer.vocabulary_.keys()))

                    # Make dictionary
                    dictionary = gensim.corpora.Dictionary(df[reduced_token_str])

                    # Make corpus
                    corpus = [dictionary.doc2bow(text) for text in df[reduced_token_str]]

                    # Serialize
                    #serial_str = 'news_{}.mm'.format(str(d))
                    #gensim.corpora.MmCorpus.serialize(serial_str, corpus)
                    #newsm = gensim.corpora.MmCorpus(serial_str)

                    # Topic model
                    for a in alphas:
                        for e in etas: 
                            lda = gensim.models.ldamodel.LdaModel(corpus=corpus, 
                                id2word=dictionary, num_topics=num, alpha=a, eta=e, random_state=random_number)

                            topicsDict = {}
                            for topicNum in range(lda.num_topics):
                                topicWords = [w for w, p in lda.show_topic(topicNum)]
                                topicsDict['Topic_{}'.format(topicNum)] = topicWords

                            wordRanksDF = pandas.DataFrame(topicsDict)
                            print('Norm: ', norm, 'Num topics: ', num, ', Max df: ', d,
                                  ' Max features: ', f, ' Alpha: ', a, ' Eta: ', e)
                            print(wordRanksDF)
                            print()

# %% [markdown]
# <br> <br>
# The rest of the notebook is a search through different parameters looking for topics that show some internal semantic consistency. The ultimate hyperparameter combination was chosen based on this, whether the words within the topic seemed to reflect a consistent theme.

# %%
# num_topics = [3,8,20]
# max_dfs = [0.5, 0.7]
# max_features = [1000, 3000]
# norm_type = [ '_stem']

# alphas = [ 0.001, 0.1, 0.5]
# etas = [0.001, 0.1, 0.5]
topic_loop(news_df, num_topics, max_dfs, max_features, norm_type, alphas, etas)
# Out:
# /home/sunjoo/.local/lib/python3.6/site-packages/gensim/models/ldamodel.py:802: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  1000  Alpha:  0.001  Eta:  0.001
#      Topic_0   Topic_1 Topic_2
# 0      trump      year    year
# 1      state      risk  nation
# 2         us   develop  report
# 3  agreement    impact      us
# 4    develop      time   trump
# 5     nation       may   state
# 6      water  research    time
# 7       year      like    like
# 8       need       say     say
# 9       work      food  carbon
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  1000  Alpha:  0.001  Eta:  0.1
#      Topic_0      Topic_1 Topic_2
# 0      trump         year    year
# 1         us       nation   state
# 2  agreement      develop    need
# 3      state       report    like
# 4      china        trump   water
# 5     nation        state     say
# 6       year           us  action
# 7    develop         like    time
# 8     accord  environment    make
# 9      power         risk    plan
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  1000  Alpha:  0.001  Eta:  0.5
#        Topic_0  Topic_1    Topic_2
# 0        state  develop      trump
# 1         year     year         us
# 2       nation     need       year
# 3        water      per      state
# 4      develop   nation       time
# 5    agreement   impact  agreement
# 6        china     cent        say
# 7         work  project     nation
# 8  environment     risk       like
# 9         need    water  scientist
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  1000  Alpha:  0.1  Eta:  0.001
#   Topic_0      Topic_1  Topic_2
# 0    year        trump  develop
# 1   state           us     year
# 2    time    agreement    state
# 3    like        state   nation
# 4     per       nation    water
# 5  nation         year     work
# 6  carbon       accord     need
# 7     use        china       us
# 8     say          say    trump
# 9    need  environment     food
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  1000  Alpha:  0.1  Eta:  0.1
#    Topic_0    Topic_1    Topic_2
# 0  develop       year      trump
# 1    state      state         us
# 2     year       like     nation
# 3    water       time  agreement
# 4   nation  scientist      state
# 5     need        say     accord
# 6     food      could       year
# 7     plan      human      china
# 8  project       make        say
# 9  support     impact     carbon
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  1000  Alpha:  0.1  Eta:  0.5
#      Topic_0  Topic_1  Topic_2
# 0      trump     year    china
# 1      state  develop  develop
# 2         us    water   nation
# 3       year      per  nigeria
# 4     nation     need       us
# 5        say     plan    state
# 6       like     cent     need
# 7  agreement  project    trade
# 8       time      use     year
# 9     report   nation    trump
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  1000  Alpha:  0.5  Eta:  0.001
#      Topic_0  Topic_1    Topic_2
# 0      trump  develop       year
# 1         us    state       like
# 2      state   nation     report
# 3     nation     year      state
# 4  agreement     need  scientist
# 5       year     work      water
# 6     accord  support   research
# 7      power    china       rise
# 8        per       us      level
# 9        say   action     impact
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  1000  Alpha:  0.5  Eta:  0.1
#    Topic_0    Topic_1  Topic_2
# 0     year      trump      per
# 1    water         us     cent
# 2    state       year  develop
# 3  develop      state   carbon
# 4   nation     nation       us
# 5     like  agreement     need
# 6   impact     accord     year
# 7   report        say    power
# 8     make      china    state
# 9     need  scientist      use
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  1000  Alpha:  0.5  Eta:  0.5
#      Topic_0    Topic_1  Topic_2
# 0         us      trump     year
# 1       year      state    water
# 2      trump    develop   report
# 3      china         us   impact
# 4     carbon     nation      use
# 5     nation  agreement  project
# 6      state       year   nation
# 7      power       work     need
# 8  agreement        say      per
# 9       need       make     risk
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  3000  Alpha:  0.001  Eta:  0.001
#    Topic_0    Topic_1  Topic_2
# 0     year      trump    water
# 1  develop         us    state
# 2   carbon      state     year
# 3   nation       year  develop
# 4    power  agreement   report
# 5     warm     nation   nation
# 6     need        say   impact
# 7     make       time   region
# 8     like     accord  project
# 9      use       like     plan
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  3000  Alpha:  0.001  Eta:  0.1
#    Topic_0    Topic_1  Topic_2
# 0      per      trump  develop
# 1     year       year    china
# 2    state         us   nation
# 3     cent      state    water
# 4   nation       warm       us
# 5   impact     nation  nigeria
# 6  develop  agreement     year
# 7      use       time     need
# 8   report       like    state
# 9   region     report  sustain
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  3000  Alpha:  0.001  Eta:  0.5
#    Topic_0  Topic_1    Topic_2
# 0     year  develop      trump
# 1  develop    state         us
# 2  project     year       year
# 3    china      per      state
# 4   nation     need     nation
# 5     need     plan       warm
# 6    water    water  agreement
# 7   invest     cent        say
# 8     risk       us       like
# 9  product   report       time
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  3000  Alpha:  0.1  Eta:  0.001
#      Topic_0    Topic_1  Topic_2
# 0      trump       year  develop
# 1         us      water     year
# 2      state       like   nation
# 3       year       need    state
# 4  agreement  scientist     need
# 5     nation        say   invest
# 6       warm     report      per
# 7     accord   research     plan
# 8       time     nation  project
# 9        say        use     cent
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  3000  Alpha:  0.1  Eta:  0.1
#        Topic_0 Topic_1  Topic_2
# 0         year   trump  develop
# 1       nation    year   nation
# 2        state      us    state
# 3          use   state    china
# 4         make    warm     year
# 5         work  report     need
# 6  environment    like    water
# 7      develop     say     plan
# 8          say    time  sustain
# 9         time  carbon   invest
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  3000  Alpha:  0.1  Eta:  0.5
#      Topic_0  Topic_1 Topic_2
# 0         us  develop    year
# 1      trump     year   trump
# 2      china   nation   state
# 3  agreement    state      us
# 4      state   invest    warm
# 5    develop   report    like
# 6     nation     need    time
# 7         mr   carbon     say
# 8     accord   impact  nation
# 9       year   action    make
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  3000  Alpha:  0.5  Eta:  0.001
#   Topic_0 Topic_1    Topic_2
# 0   trump    year    develop
# 1    year  report     nation
# 2      us     per      china
# 3   state   state         us
# 4  nation   water      state
# 5    time  impact  agreement
# 6     say   could       plan
# 7    make    cent      trump
# 8    like    like       need
# 9    need    warm     carbon
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  3000  Alpha:  0.5  Eta:  0.1
#      Topic_0  Topic_1    Topic_2
# 0       year    water      trump
# 1     nation     year         us
# 2       warm   report      state
# 3      state   impact  agreement
# 4      trump    state    develop
# 5  scientist      use       year
# 6      china     risk     nation
# 7         us  develop     carbon
# 8      human      per        say
# 9       time     like       need
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  3000  Alpha:  0.5  Eta:  0.5
#      Topic_0  Topic_1  Topic_2
# 0       year     year    state
# 1      trump  develop    trump
# 2         us   nation     year
# 3     report    state    water
# 4  agreement     warm   nation
# 5      state     time       us
# 6       warm     like      say
# 7       need    china  develop
# 8     nation       us     like
# 9     carbon   carbon     work
#
# Norm:  _stem Num topics:  3 , Max df:  0.7  Max features:  1000  Alpha:  0.001  Eta:  0.001
#   Topic_0    Topic_1 Topic_2
# 0    said       said    said
# 1   state      trump    year
# 2   trump      world  global
# 3      us    develop   world
# 4    also     global     new
# 5  global     nation    like
# 6  nation       year     one
# 7   would      china   would
# 8   world         us    also
# 9     one  agreement    time
# Norm:  _stem Num topics:  3 , Max df:  0.7  Max features:  1000  Alpha:  0.001  Eta:  0.1
#   Topic_0  Topic_1 Topic_2
# 0    year     said    said
# 1    said    trump    year
# 2   would       us    also
# 3  global   global  report
# 4   trump    state   state
# 5     one    world  nation
# 6   world     year  global
# 7     say  develop    risk
# 8   water     also  impact
# 9    like    china    fund
#
# Norm:  _stem Num topics:  3 , Max df:  0.7  Max features:  1000  Alpha:  0.001  Eta:  0.5
#   Topic_0  Topic_1    Topic_2
# 0    said     said      trump
# 1    year  develop         us
# 2   state    china       said
# 3    also    world     global
# 4     one     year      state
# 5  global   global  agreement
# 6  nation   nation      world
# 7   world      new       year
# 8   would     also       also
# 9   trump    would      would
#
# Norm:  _stem Num topics:  3 , Max df:  0.7  Max features:  1000  Alpha:  0.1  Eta:  0.001
#      Topic_0  Topic_1  Topic_2
# 0       said     said  develop
# 1      trump     year     year
# 2      state    water      new
# 3         us     also   global
# 4     global    world      one
# 5  agreement   nation    world
# 6      world   global     also
# 7       year    would     need
# 8      would      per       us
# 9     nation  develop     like
#
# Norm:  _stem Num topics:  3 , Max df:  0.7  Max features:  1000  Alpha:  0.1  Eta:  0.1
#    Topic_0 Topic_1  Topic_2
# 0     said    said     said
# 1     year   trump   nation
# 2     also      us  develop
# 3  project    year    state
# 4    world  global    water
# 5      one   world   global
# 6   global   would   impact
# 7    water   state     also
# 8     work     new     year
# 9  develop    also  nigeria
#
# Norm:  _stem Num topics:  3 , Max df:  0.7  Max features:  1000  Alpha:  0.1  Eta:  0.5
#   Topic_0    Topic_1 Topic_2
# 0   trump       said    said
# 1      us    develop    year
# 2  global     nation   state
# 3   world      state    also
# 4    year      world   water
# 5    said     global  report
# 6   would  agreement     one
# 7     new       also  global
# 8  carbon       year  impact
# 9     one      trump    like
#
# Norm:  _stem Num topics:  3 , Max df:  0.7  Max features:  1000  Alpha:  0.5  Eta:  0.001
#    Topic_0 Topic_1    Topic_2
# 0     said    said     global
# 1  develop    year         us
# 2     also   trump      trump
# 3   nation   state      world
# 4    state   would       said
# 5      new   world  agreement
# 6    water    also     nation
# 7     need  global        new
# 8   global      us      power
# 9      one  report       year
#
# Norm:  _stem Num topics:  3 , Max df:  0.7  Max features:  1000  Alpha:  0.5  Eta:  0.1
#    Topic_0 Topic_1 Topic_2
# 0     said    said    year
# 1    state  global   world
# 2     year   trump  nation
# 3     also   world      us
# 4   global      us    said
# 5  develop    year   trump
# 6   nation     new    also
# 7    would   would  global
# 8   report     one   water
# 9    trump    also   power
#
# Norm:  _stem Num topics:  3 , Max df:  0.7  Max features:  1000  Alpha:  0.5  Eta:  0.5
#   Topic_0 Topic_1  Topic_2
# 0    said    said     said
# 1    year   trump   global
# 2   state  nation    world
# 3     one    also     year
# 4   would  global    china
# 5  global      us       us
# 6   trump   world  develop
# 7    like   state     also
# 8    time     new   report
# 9    also   would      new
#
# Norm:  _stem Num topics:  3 , Max df:  0.7  Max features:  3000  Alpha:  0.001  Eta:  0.001
#    Topic_0 Topic_1  Topic_2
# 0     said    said     year
# 1    trump    year   global
# 2    state      us    world
# 3   nation   trump     said
# 4  develop   would    water
# 5      new    also     also
# 6   global   world      one
# 7    would   state       us
# 8    world  global    state
# 9     also     say  develop
#
# Norm:  _stem Num topics:  3 , Max df:  0.7  Max features:  3000  Alpha:  0.001  Eta:  0.1
#   Topic_0 Topic_1  Topic_2
# 0    said    said     said
# 1  global   trump  develop
# 2   world    year   nation
# 3    also   state     also
# 4     new  global     year
# 5      us      us    state
# 6   trump    warm    world
# 7    year   would   global
# 8   china     one      per
# 9    need   world     plan
#
# Norm:  _stem Num topics:  3 , Max df:  0.7  Max features:  3000  Alpha:  0.001  Eta:  0.5
#   Topic_0  Topic_1    Topic_2
# 0    said     said      trump
# 1    year  develop       said
# 2  global   nation      state
# 3    also   global         us
# 4   water    world      would
# 5  report  nigeria      world
# 6   world     year  agreement
# 7     per     also       also
# 8     one      new       year
# 9    warm    china     global
#
# Norm:  _stem Num topics:  3 , Max df:  0.7  Max features:  3000  Alpha:  0.1  Eta:  0.001
#      Topic_0  Topic_1    Topic_2
# 0       said     said       said
# 1       year  develop      trump
# 2     global     also     global
# 3       warm    state         us
# 4      trump   nation      world
# 5         us    water  agreement
# 6       like     year      would
# 7       time     need      state
# 8        one  nigeria       year
# 9  scientist      one       also
#
# Norm:  _stem Num topics:  3 , Max df:  0.7  Max features:  3000  Alpha:  0.1  Eta:  0.1
#    Topic_0    Topic_1 Topic_2
# 0     said       said    said
# 1     also       year   trump
# 2    world    develop   state
# 3     year     nation  global
# 4   global         us    year
# 5  develop     global      us
# 6      one      trump   would
# 7      new      world    warm
# 8    state  agreement   world
# 9    would       also  nation
#
# Norm:  _stem Num topics:  3 , Max df:  0.7  Max features:  3000  Alpha:  0.1  Eta:  0.5
#    Topic_0  Topic_1    Topic_2
# 0     year     said       said
# 1   global     year      trump
# 2     said    water         us
# 3    world     also      state
# 4     warm  develop      world
# 5   carbon   nation     global
# 6  develop    state      would
# 7     also  project  agreement
# 8    would      one     nation
# 9   nation      new       also
#
# Norm:  _stem Num topics:  3 , Max df:  0.7  Max features:  3000  Alpha:  0.5  Eta:  0.001
#   Topic_0    Topic_1 Topic_2
# 0    said       said    said
# 1    year      state   trump
# 2    warm     nation  global
# 3  global    develop    year
# 4    also      world   world
# 5    like         us   would
# 6     one       year   state
# 7   world       also      us
# 8      us  agreement    also
# 9   water     action     new
#
# Norm:  _stem Num topics:  3 , Max df:  0.7  Max features:  3000  Alpha:  0.5  Eta:  0.1
#    Topic_0    Topic_1 Topic_2
# 0     said      trump    said
# 1   global       said    year
# 2    world         us  global
# 3  develop      state   would
# 4      one     nation    warm
# 5     time    develop   state
# 6     also      world    also
# 7    water       also     one
# 8     year  agreement   world
# 9    would       year    like
#
# Norm:  _stem Num topics:  3 , Max df:  0.7  Max features:  3000  Alpha:  0.5  Eta:  0.5
#    Topic_0  Topic_1 Topic_2
# 0     said   global    said
# 1     year    world   trump
# 2       us     said   state
# 3   nation     year    year
# 4    world      new  global
# 5       mr  develop   would
# 6    would     also    also
# 7   global       us   world
# 8  develop      one     one
# 9     also     make  nation
#
# Norm:  _stem Num topics:  8 , Max df:  0.5  Max features:  1000  Alpha:  0.001  Eta:  0.001
#        Topic_0  Topic_1    Topic_2  Topic_3    Topic_4  Topic_5    Topic_6  \
# 0       nation     year       year  develop    develop     year         us
# 1  environment   report  scientist    water    nigeria      per      trump
# 2       forest     risk      human     need     nation     food  agreement
# 3      project       us       like     plan      china      uae      state
# 4        state      per       rise   nation         us     cent      power
# 5      develop  weather        say     year      state  billion       coal
# 6          law     need       time    green  agreement    china     accord
# 7        women     like      flood      use    support  project        say
# 8         year     time        sea     work      trade   market     carbon
# 9      protect     cent      level     make       year  million       year
#
#      Topic_7
# 0      trump
# 1      state
# 2         us
# 3         mr
# 4     nation
# 5       year
# 6  agreement
# 7     accord
# 8     carbon
# 9       time
#
# Norm:  _stem Num topics:  8 , Max df:  0.5  Max features:  1000  Alpha:  0.001  Eta:  0.1
#    Topic_0  Topic_1      Topic_2    Topic_3    Topic_4  Topic_5    Topic_6  \
# 0    china   report      develop       year      state  develop      trump
# 1    power     year  environment  scientist     nation     fund         us
# 2     plan    flood         year     carbon    develop     bank      state
# 3      per     risk          uae   research      water     need  agreement
# 4     cent     need         food      level      china   nation     nation
# 5     coal      say         work       like  agreement     year       year
# 6  develop   nation        local      could      trump   africa     accord
# 7     meet     like        china     impact       year  support        say
# 8   target  weather       nation      human     summit  project     report
# 9     year     time         plan       rise     carbon   sector   american
#
#   Topic_7
# 0   water
# 1    year
# 2  forest
# 3     use
# 4     per
# 5    time
# 6   plant
# 7    food
# 8    like
# 9   state
# Norm:  _stem Num topics:  8 , Max df:  0.5  Max features:  1000  Alpha:  0.001  Eta:  0.5
#      Topic_0    Topic_1 Topic_2    Topic_3  Topic_4  Topic_5  Topic_6  \
# 0       year       year    like      trump  develop      per  nigeria
# 1  scientist         us    year         us     food     plan  develop
# 2     report       fuel   water  agreement     year     year    india
# 3     nation    develop     use      state    china    state   nation
# 4       rise     fossil   flood      china   africa     cent    state
# 5        say        oil    time     accord   market     need   forest
# 6       like        gas   human     nation   nation  develop    water
# 7        sea  agreement    need         mr   region      say    level
# 8    weather     nation  impact     leader  african      use  protect
# 9      level     action    even       year     work   nation   effect
#
#        Topic_7
# 0        water
# 1        state
# 2         year
# 3  environment
# 4       nation
# 5      project
# 6      develop
# 7       report
# 8         need
# 9        dubai
#
# Norm:  _stem Num topics:  8 , Max df:  0.5  Max features:  1000  Alpha:  0.1  Eta:  0.001
#    Topic_0    Topic_1    Topic_2    Topic_3    Topic_4  Topic_5      Topic_6  \
# 0      per         us      trump       year    develop    china        state
# 1     year  agreement         us      state       year  develop        trump
# 2     cent      trump     accord  scientist      india     year       nation
# 3   carbon      state      china      water     nation    power           mr
# 4    water       year       meet       like  agreement   nation      nigeria
# 5     need    develop  agreement     report     action   market  environment
# 6      use     nation      state   research      china   africa         plan
# 7   report       like     summit    weather      state     need         work
# 8      oil       make     leader        say       meet    trade           us
# 9  project        uae     nation       time         us       us       action
#
#   Topic_7
# 0    risk
# 1   green
# 2    coal
# 3    fund
# 4    year
# 5   power
# 6    like
# 7    make
# 8      us
# 9    need
#
# Norm:  _stem Num topics:  8 , Max df:  0.5  Max features:  1000  Alpha:  0.1  Eta:  0.1
#   Topic_0    Topic_1      Topic_2    Topic_3  Topic_4  Topic_5 Topic_6  \
# 0   trump      trump  environment       year    water  develop     per
# 1   state         us       forest    weather     year   nation    cent
# 2    year  agreement          say  scientist  develop    state    year
# 3    make      china        plant         us      use     work  carbon
# 4    time         mr           us      state   region     need     gas
# 5    like      state        state      flood   nation     plan  report
# 6  nation     nation          use     report     food  support     uae
# 7     say     accord         plan     action     need     year   could
# 8      us    develop       action       time   impact  nigeria  impact
# 9    need       meet         need       like  project    china   power
#
#    Topic_7
# 0     year
# 1    state
# 2  nigeria
# 3     rise
# 4   nation
# 5   report
# 6      sea
# 7    level
# 8    trump
# 9   effect
#
# Norm:  _stem Num topics:  8 , Max df:  0.5  Max features:  1000  Alpha:  0.1  Eta:  0.5
#     Topic_0    Topic_1 Topic_2    Topic_3      Topic_4 Topic_5    Topic_6  \
# 0     china       year   state         us      develop   water     health
# 1   develop     report    like        per      nigeria    year     action
# 2      year       rise    year     carbon       nation     use      water
# 3    region  scientist    time       cent        state  nation  agreement
# 4      data      level   trump       year      project  forest         us
# 5  research     impact     say      power      support  school       year
# 6      food      human      us  agreement  environment    food        per
# 7        us        sea    make        gas       action    area     nation
# 8    nation   research    need      trump         fund    need       cent
# 9   percent    weather   flood       coal         plan    land       bill
#
#      Topic_7
# 0      trump
# 1         us
# 2      state
# 3  agreement
# 4      china
# 5     nation
# 6       year
# 7     accord
# 8     leader
# 9    develop
#
# Norm:  _stem Num topics:  8 , Max df:  0.5  Max features:  1000  Alpha:  0.5  Eta:  0.001
#      Topic_0    Topic_1 Topic_2      Topic_3  Topic_4  Topic_5    Topic_6  \
# 0      trump      water     per        trump  develop    green    develop
# 1         us       year    year           us    china     year      china
# 2       year      could    cent        state  nigeria     even      india
# 3  agreement        use  report    agreement   nation     fund       need
# 4         mr        say   state       nation     year  develop  agreement
# 5       coal    weather  nation          say   africa     time       year
# 6        gas       like  impact       accord  support     need       plan
# 7       fuel     impact  carbon         year    trade    water      power
# 8     carbon   research   level       report       us   accord       meet
# 9        oil  scientist    plan  environment    state   nation     summit
#
#   Topic_7
# 0    year
# 1    need
# 2   state
# 3    like
# 4  nation
# 5    make
# 6    work
# 7   human
# 8    time
# 9      go
#
# Norm:  _stem Num topics:  8 , Max df:  0.5  Max features:  1000  Alpha:  0.5  Eta:  0.1
#    Topic_0  Topic_1   Topic_2    Topic_3      Topic_4   Topic_5    Topic_6  \
# 0    water    china      year      state      nigeria      year      trump
# 1  develop  develop   percent       year       nation      food         us
# 2    state   nation      time        say      develop       use  agreement
# 3    flood     year      need  scientist          per       uae      state
# 4   impact    power      make      human         cent    report     accord
# 5     year    trade       day       time         need   develop     nation
# 6     need       us  research       rise       forest     india        gas
# 7     like  support      coal      trump  environment    nation        oil
# 8     plan     need     could        use         year  research     report
# 9     work    state    action     report        state        al       year
#
#   Topic_7
# 0    year
# 1      us
# 2  carbon
# 3      mr
# 4    risk
# 5    like
# 6     per
# 7    need
# 8  nation
# 9  action
#
# Norm:  _stem Num topics:  8 , Max df:  0.5  Max features:  1000  Alpha:  0.5  Eta:  0.5
#    Topic_0    Topic_1    Topic_2      Topic_3  Topic_4   Topic_5    Topic_6  \
# 0    china      water    develop       report     year        mr      trump
# 1     year       year     nation         year    china      work         us
# 2    water      level      state  environment  develop    leader      state
# 3    state       rise  agreement         need     need      year  agreement
# 4     time      flood        per         food  nigeria  scotland     nation
# 5     risk        sea       year        green     bank       see     accord
# 6      say  scientist       cent         like     like       say       time
# 7   carbon      state      power       impact       us    nation   american
# 8       us   research    project       health   market      need       year
# 9  develop    weather       coal          use   nation      make     action
#
#    Topic_7
# 0    state
# 1   nation
# 2   carbon
# 3     year
# 4       us
# 5  develop
# 6     like
# 7     make
# 8     work
# 9    human
#
# Norm:  _stem Num topics:  8 , Max df:  0.5  Max features:  3000  Alpha:  0.001  Eta:  0.001
#    Topic_0    Topic_1      Topic_2  Topic_3   Topic_4  Topic_5  Topic_6  \
# 0    power      trump      develop   farmer     water     year     year
# 1   nation         us       nation     bond   develop     food    state
# 2     year  agreement        china    green       per   report    water
# 3    state      state      sustain     food      year      say  develop
# 4      per     nation         year   market      cent  product     time
# 5  develop       year         need  develop    nation     rise     need
# 6    india     accord       region  product      need     land     plan
# 7     cent     carbon         plan     year   sustain     tree     like
# 8     coal         mr         work     need  research     make     make
# 9    china       unit  environment    china    invest    plant   nation
#
#      Topic_7
# 0       warm
# 1       year
# 2  scientist
# 3    weather
# 4     report
# 5       like
# 6      state
# 7      storm
# 8       rise
# 9      flood
# Norm:  _stem Num topics:  8 , Max df:  0.5  Max features:  3000  Alpha:  0.001  Eta:  0.1
#   Topic_0    Topic_1   Topic_2 Topic_3    Topic_4    Topic_5   Topic_6  \
# 0    year  agreement    invest   water      trump       warm   develop
# 1    time       year   develop     per         us      trump     state
# 2    make         mr      year    year  agreement       year      plan
# 3    work       coal      risk    cent      state       like   sustain
# 4   state         us    carbon    food      china     report  research
# 5      us     nation       oil  farmer     accord        say     water
# 6     say     carbon  investor   state     nation      state    impact
# 7  nation      state      fund    need       unit  scientist    forest
# 8   human      plant      need  report     commit       rise      year
# 9   think        per       gas  nation       deal      storm    nation
#
#     Topic_7
# 0    nation
# 1     china
# 2        us
# 3     state
# 4   develop
# 5      year
# 6   nigeria
# 7     trump
# 8      need
# 9  nigerian
#
# Norm:  _stem Num topics:  8 , Max df:  0.5  Max features:  3000  Alpha:  0.001  Eta:  0.5
#        Topic_0  Topic_1    Topic_2      Topic_3  Topic_4  Topic_5    Topic_6  \
# 0      student     year       year        trump     food  develop         us
# 1        state    state       warm       nation   farmer   nation      trump
# 2  environment      say     carbon        state    water    state  agreement
# 3         year     like       time           us     year    water      state
# 4         plan     need         us  environment  product     year      china
# 5      support   impact  scientist         like      use      per     accord
# 6         make     risk    weather        human   impact  nigeria     nation
# 7         work  develop        say         make     farm  project       year
# 8         need   report       like          say     area     cent       unit
# 9      sustain   nation     report         year     need   report     commit
#
#     Topic_7
# 0     trump
# 1     china
# 2        us
# 3     trade
# 4     state
# 5    nation
# 6       say
# 7  european
# 8      year
# 9      meet
#
# Norm:  _stem Num topics:  8 , Max df:  0.5  Max features:  3000  Alpha:  0.1  Eta:  0.001
#      Topic_0  Topic_1 Topic_2   Topic_3    Topic_4  Topic_5      Topic_6  \
# 0      trump    china    year    impact      trump    water      develop
# 1         us   market     per    report         us     year       nation
# 2       year   invest    cent     water  agreement    state      sustain
# 3      state     year    fund     state      state     like      nigeria
# 4       warm  develop    need      year     nation     warm         need
# 5        say    green    make  research      china     need         work
# 6     nation       us   green      risk    develop  develop  environment
# 7  scientist     make  farmer       per         mr   forest     nigerian
# 8       like     need  invest     could     leader   effect       africa
# 9       time   growth     say      rise     commit     plan         year
#
#    Topic_7
# 0  student
# 1     year
# 2    plant
# 3   report
# 4   carbon
# 5    power
# 6     make
# 7  percent
# 8     like
# 9     work
#
# Norm:  _stem Num topics:  8 , Max df:  0.5  Max features:  3000  Alpha:  0.1  Eta:  0.1
#    Topic_0    Topic_1   Topic_2    Topic_3 Topic_4    Topic_5   Topic_6  \
# 0    water       time      year      trump    year         us   develop
# 1     food      human      rise      state   state      trump    nation
# 2   farmer       warm      warm         us     per         mr   nigeria
# 3     year  scientist  research  agreement  carbon  agreement   sustain
# 4  develop       year    report     nation    make     nation     state
# 5     need     nation      like       unit    cent      india  nigerian
# 6      use        say   weather     accord     say      state      year
# 7  product       like     flood       year   power     accord   project
# 8   region       make     could      china  nation     commit      work
# 9  project         us       sea     action    like       year      need
#
#   Topic_7
# 0    year
# 1    fund
# 2  report
# 3  impact
# 4    risk
# 5   state
# 6  action
# 7  invest
# 8  carbon
# 9    plan
#
# Norm:  _stem Num topics:  8 , Max df:  0.5  Max features:  3000  Alpha:  0.1  Eta:  0.5
#    Topic_0  Topic_1    Topic_2    Topic_3  Topic_4   Topic_5  Topic_6  \
# 0     year    power      state       year  develop     water     year
# 1    state     year     report        say  nigeria    invest    state
# 2       us    china       year       warm   nation      year    flood
# 3    china  develop       warm       like  sustain      risk  weather
# 4   nation    india      level       time    state      fund    storm
# 5     make   nation  scientist        per     plan      need   farmer
# 6  develop      uae   research        use  project   develop     time
# 7     need     coal     impact       cent     need       oil     like
# 8   africa    plant     nation  scientist     work       per   harvey
# 9   report    solar       rise      could    water  investor    water
#
#      Topic_7
# 0      trump
# 1         us
# 2  agreement
# 3      state
# 4     nation
# 5     accord
# 6       year
# 7         mr
# 8       unit
# 9      china
#
# Norm:  _stem Num topics:  8 , Max df:  0.5  Max features:  3000  Alpha:  0.5  Eta:  0.001
#   Topic_0    Topic_1    Topic_2    Topic_3    Topic_4   Topic_5  Topic_6  \
# 0   state      trump      trump    develop       year    invest     year
# 1    year         us      state     nation       warm       per    flood
# 2    like       year         us    nigeria     report      food    human
# 3  report      state  agreement       year  scientist      year     make
# 4      us  agreement     nation      china       time    farmer  weather
# 5    time     carbon     accord      state       like      cent    water
# 6   trump      power       year    support   research      need      use
# 7   india        say      china    sustain      could      risk     work
# 8  nation     action        say  agreement        say   product     like
# 9    warm       make       unit       need     carbon  investor    event
#
#        Topic_7
# 0        water
# 1      develop
# 2  environment
# 3         plan
# 4      project
# 5        state
# 6         need
# 7          use
# 8         fund
# 9      sustain
#
# Norm:  _stem Num topics:  8 , Max df:  0.5  Max features:  3000  Alpha:  0.5  Eta:  0.1
#     Topic_0    Topic_1 Topic_2  Topic_3    Topic_4  Topic_5      Topic_6  \
# 0       per      trump   state    water       year  develop  environment
# 1      year         us    work     food       warm   nation         year
# 2      cent      state    make   report  scientist   invest       carbon
# 3      time  agreement    year    flood        say     year      sustain
# 4        uk     accord      us     year     nation    state         fund
# 5     level     nation  carbon     need       time  project      develop
# 6     storm       unit    need   impact       like  nigeria         need
# 7     could       year  nation  product    weather     plan         risk
# 8  research     action   human     like      state     need       nation
# 9      warm   american     say      per       last    green       report
#
#    Topic_7
# 0     year
# 1     rise
# 2   action
# 3      say
# 4   report
# 5     like
# 6    earth
# 7  support
# 8     time
# 9  develop
#
# Norm:  _stem Num topics:  8 , Max df:  0.5  Max features:  3000  Alpha:  0.5  Eta:  0.5
#      Topic_0      Topic_1  Topic_2  Topic_3 Topic_4   Topic_5  Topic_6  \
# 0      trump        state  develop  nigeria     per     china     year
# 1         us         year   invest  develop    cent      year  develop
# 2      state       nation  sustain   nation    risk   develop   carbon
# 3  agreement         work    green     fund    year     power    india
# 4     accord         time   nation    water  farmer    nation    water
# 5     nation  environment     need   africa    need  nigerian   impact
# 6       unit       forest  project   region    food      need     need
# 7         mr         make  support     year   could   nigeria      per
# 8     leader         like     bank  project  report   sustain   nation
# 9   american           us   sector    china    like     state     make
#
#      Topic_7
# 0       year
# 1       warm
# 2  scientist
# 3     report
# 4      state
# 5       time
# 6        say
# 7        sea
# 8    weather
# 9      level
# Norm:  _stem Num topics:  8 , Max df:  0.7  Max features:  1000  Alpha:  0.001  Eta:  0.001
#    Topic_0    Topic_1   Topic_2  Topic_3  Topic_4 Topic_5  Topic_6   Topic_7
# 0   global       said       per     said  develop    year     said    carbon
# 1    world      trump  scotland       us     said     one    water      said
# 2    china      state      cent     year  project    like     also      year
# 3     said         us      said    world     also    time     year  research
# 4       us  agreement       new  develop     risk     say    level     world
# 5    india     global      year    state     fund   would   global    global
# 6  develop     nation      also  nigeria     plan    make  nigeria     power
# 7     year      would    global   action   nation   world    world       gas
# 8     also     report    report   nation    green  global      sea       new
# 9   nation       also        uk   global     year   human     rise      also
#
# Norm:  _stem Num topics:  8 , Max df:  0.7  Max features:  1000  Alpha:  0.001  Eta:  0.1
#   Topic_0    Topic_1  Topic_2 Topic_3  Topic_4    Topic_5  Topic_6  \
# 0    said      trump     said   state     year       said     said
# 1   water       said  develop   would    world   research    state
# 2     per         us   nation  action   global      would   global
# 3    cent  agreement     also  carbon     like       year    china
# 4    year      world  nigeria  global  weather     report   report
# 5    need      state    state     one      one        new    power
# 6    also     global  project     new     time  scientist  percent
# 7      mr     accord     year   world     said      could     also
# 8     use       also    world    year    human     global    world
# 9     say     nation   impact    like    storm       rise     year
#
#        Topic_7
# 0       global
# 1         said
# 2           mr
# 3        trump
# 4        would
# 5          say
# 6           us
# 7  environment
# 8         year
# 9       carbon
#
# Norm:  _stem Num topics:  8 , Max df:  0.7  Max features:  1000  Alpha:  0.001  Eta:  0.5
#   Topic_0    Topic_1    Topic_2  Topic_3 Topic_4  Topic_5  Topic_6 Topic_7
# 0    year       said      trump  develop    said    china    world    said
# 1  global      water       said     work    year   global  develop     per
# 2    also     global      state   nation    also    world     year    cent
# 3    like       year         us     need    time  develop      one   would
# 4     one     report  agreement    local     one     said     also    year
# 5    said       also     nation     plan    need       us   global  carbon
# 6    time        say      would    build    food    india   africa     new
# 7   storm   research     accord     said   world     year   nation    also
# 8   would      world     global   region   state      new    state    fund
# 9   level  scientist      world    state   plant     also      new   power
#
# Norm:  _stem Num topics:  8 , Max df:  0.7  Max features:  1000  Alpha:  0.1  Eta:  0.001
#      Topic_0  Topic_1    Topic_2  Topic_3  Topic_4  Topic_5 Topic_6 Topic_7
# 0       said     said      trump     said      per    water    said    said
# 1       year   nation         us  develop     cent    india   state   state
# 2     global    world       said   global     said     also  report    also
# 3        one  develop  agreement    world     year    china  nation    year
# 4       like   global     global  nigeria  develop     need    also   flood
# 5  scientist    state      state     also    power  develop   trump      us
# 6      human    china      would     year    would     plan     new     one
# 7       also     also      world   nation    china     fund    meet  forest
# 8       time      new         mr    state      new       us  public  action
# 9      would  nigeria     carbon     need    plant    state     one  impact
#
# Norm:  _stem Num topics:  8 , Max df:  0.7  Max features:  1000  Alpha:  0.1  Eta:  0.1
#    Topic_0    Topic_1 Topic_2  Topic_3 Topic_4  Topic_5    Topic_6    Topic_7
# 0     said      trump    said   nation    said     said      trump     global
# 1  develop         us    year  nigeria      mr    trump         us       year
# 2   report       said   water  develop   state   global        say     carbon
# 3     risk  agreement    also    green      us       us  agreement       time
# 4   nation      world  impact     said    also    world     nation      world
# 5     also     global    need    state   would     year      world        new
# 6   global      china     one    would   power    state      state         us
# 7   region     accord     per     also  global      one       year      human
# 8    state      state   state     fund    plan  percent       said  scientist
# 9    world        new   flood  project   world     like      would       also
#
# Norm:  _stem Num topics:  8 , Max df:  0.7  Max features:  1000  Alpha:  0.1  Eta:  0.5
#   Topic_0    Topic_1 Topic_2 Topic_3 Topic_4  Topic_5  Topic_6    Topic_7
# 0     per       said     one    said  global     said  develop      trump
# 1    year       year    also      mr    said    state    world       said
# 2    cent     global     say   would   world    water   nation         us
# 3      us     report    year     one    year  develop   global  agreement
# 4    also    weather    like    year   water     year     also     global
# 5  carbon  scientist      us     say     new     also     said      world
# 6     gas      state    make  global    time   forest   africa      china
# 7   would     nation    time      us    also  project     need      state
# 8     new       rise    need    plan   green   action     year       year
# 9   trump      world   water    work    risk     plan  nigeria      would
#
# Norm:  _stem Num topics:  8 , Max df:  0.7  Max features:  1000  Alpha:  0.5  Eta:  0.001
#      Topic_0 Topic_1 Topic_2 Topic_3    Topic_4  Topic_5 Topic_6  Topic_7
# 0      trump     one   world    said       year     said   world     said
# 1         us    time    said   state       said    state   would     year
# 2       said   world  global      us     global   report     new      per
# 3  agreement     say  forest  nation  scientist     also     per     also
# 4     global    said   water    year   research    water   power  develop
# 5      state   water    also   trump        one   nation    year      uae
# 6      world    need  nation   world        say   health    also   market
# 7      would    year      us    also       also    would    cent     cent
# 8     nation   flood    year    work       like   impact    need      new
# 9    develop  harvey     one   would       time  develop     one   nation
#
# Norm:  _stem Num topics:  8 , Max df:  0.7  Max features:  1000  Alpha:  0.5  Eta:  0.1
#    Topic_0      Topic_1    Topic_2 Topic_3  Topic_4   Topic_5 Topic_6  Topic_7
# 0     said         said      trump   trump     said      said    said   nation
# 1  develop        water         us      us     year     state   trump    state
# 2   global         also      would   world    world      year  global      new
# 3    world       global  agreement   power    would      also      us   global
# 4    china  environment       year    cent      new    report  nation  develop
# 5   nation         need        one      mr  weather     water   would    human
# 6     also      develop       also     per  develop      rise   world      law
# 7    state       region       make    said      say    global    year    world
# 8     year        world      world   india      one    impact  accord  protect
# 9  support          one       like     new     time  research     oil    right
#
# Norm:  _stem Num topics:  8 , Max df:  0.7  Max features:  1000  Alpha:  0.5  Eta:  0.5
#   Topic_0  Topic_1    Topic_2    Topic_3 Topic_4    Topic_5  Topic_6  Topic_7
# 0   trump  develop       said       said      us       said     said     said
# 1    said    china      trump       year  global    develop     year    state
# 2     say     said      state     global    year    nigeria  project    would
# 3   world    water         us  scientist    like       also    water      new
# 4      us   nation     global        one    time     nation      per     also
# 5   would     also      world    weather  carbon     global     also     year
# 6  accord    india      would       also    said      world    world  develop
# 7  nation   global       also     impact     one  agreement      new   nation
# 8    cent       us  agreement       like  nation      green   forest     plan
# 9     per     year       year       rise   world       need     cent     work
# Norm:  _stem Num topics:  8 , Max df:  0.7  Max features:  3000  Alpha:  0.001  Eta:  0.001
#      Topic_0  Topic_1 Topic_2  Topic_3  Topic_4  Topic_5   Topic_6  Topic_7
# 0      trump     said    warm     said     said     said      said     said
# 1         us  develop   would     year      per    china   develop    water
# 2       said    world    year    state     cent  develop      year     also
# 3  agreement     also   state  student     year  nigeria       use   report
# 4     global     year    said      one   global   global      also   impact
# 5      world   nation    time    world     need   nation     world     year
# 6      state      one  global     also      new    world       one    state
# 7      would    china     say      new    green     also      make   global
# 8     nation   global    like   school   invest     year       new   nation
# 9     accord    would     one    event  project       us  research  develop
#
# Norm:  _stem Num topics:  8 , Max df:  0.7  Max features:  3000  Alpha:  0.001  Eta:  0.1
#    Topic_0  Topic_1 Topic_2    Topic_3  Topic_4  Topic_5  Topic_6 Topic_7
# 0    world     said      us       said     said     year     said    said
# 1   global  nigeria   trump      trump     year    water   invest    year
# 2    china  develop    said      state     also      per    china    also
# 3     said   nation   world         us   global   global  develop     one
# 4      one     also  carbon      would    world      use      new   would
# 5     year    state  global     report    water      one     year    make
# 6     also  sustain   power     global    state    world  project     say
# 7    power    world     gas       year  student  develop   global  global
# 8       us     plan  nation  agreement   forest     also    would    like
# 9  develop     year     new       warm     work     warm     work     new
#
# Norm:  _stem Num topics:  8 , Max df:  0.7  Max features:  3000  Alpha:  0.001  Eta:  0.5
#    Topic_0 Topic_1  Topic_2  Topic_3 Topic_4    Topic_5 Topic_6  Topic_7
# 0  develop     per  develop     said    year      trump   state     said
# 1   global    cent     said  nigeria    said       said    said     year
# 2     year    said   global  develop   would         us  nation    water
# 3     said   power  sustain    world     say     global    also     also
# 4    world    year   nation     also     one  agreement   trump      one
# 5   nation  carbon    green    state  global      state    year    state
# 6   action   world  project   nation     new      world   china   impact
# 7   report   plant     work   africa  carbon      would   world     warm
# 8     need    also    china     year    time     nation     new  weather
# 9    state     uae     bond     need   world     accord    meet    flood
#
# Norm:  _stem Num topics:  8 , Max df:  0.7  Max features:  3000  Alpha:  0.1  Eta:  0.001
#    Topic_0  Topic_1 Topic_2  Topic_3  Topic_4    Topic_5  Topic_6   Topic_7
# 0     said   global  global  develop    china      trump     said      said
# 1     year   nation    said     said   global       said     year      also
# 2    water      one    year   nation       us         us   global     state
# 3   report     also     new  nigeria     said      state    world     world
# 4     warm    world    also    state      new  agreement     also      year
# 5      one     year   world     fund  develop      would     warm      food
# 6     like      new  invest  sustain    world     global      new  research
# 7  weather  develop  region     also     year      world   carbon   develop
# 8      per     time   china    world    trade     action  percent    global
# 9   global    would      uk  project      one     nation    would    farmer
#
# Norm:  _stem Num topics:  8 , Max df:  0.7  Max features:  3000  Alpha:  0.1  Eta:  0.1
#    Topic_0 Topic_1 Topic_2 Topic_3 Topic_4    Topic_5   Topic_6  Topic_7
# 0     said    said    said   trump  global       said      said  develop
# 1    china   world    year    said    said  agreement   develop   nation
# 2   global    also   water     one   trump      state      food     said
# 3  develop   state    also      us      us     nation     world  sustain
# 4   invest      us     per   state    year         us       new    world
# 5       us  global     one    warm   state    develop      also     need
# 6   nation  forest     say    year   world      world       use    china
# 7    world  nation    need     new  carbon      would   product     year
# 8    green   would    cent    time  report       also      year     also
# ...
# 9     also   sector   support           us     land         us         mr
#
#   Topic_15  Topic_16  Topic_17 Topic_18  Topic_19    Topic_2    Topic_3  \
# 0    china       uae     power   global      said     nation       said
# 1     said      said    global  develop       per     global       year
# 2    india        al      coal     said      year  agreement       warm
# 3     year    nation      year    women      cent      world        one
# 4       us    health     plant    world  investor    develop      storm
# 5  develop    global     world    saudi    invest       year      human
# 6    world  research    impact   africa     green     commit  scientist
# 7   global     state      said     also    report     action        say
# 8   nation     india  research  sustain      need       also       like
# 9      new      also      warm    china   billion        new       time
#
#   Topic_4   Topic_5   Topic_6      Topic_7  Topic_8  Topic_9
# 0    said      year     china         said     said     said
# 1  global   weather      said         tree     fund    state
# 2  report      like        eu        plant  develop   forest
# 3    year      said     trade         also     also   action
# 4     sea     could  european  environment    state     plan
# 5     ice  research      meet      project     risk      sea
# 6   would      warm    global        world    would      new
# 7   could       say    macron        green   action  protect
# 8    rise      time   develop        dubai  support    world
# 9    warm      also      also      develop   nation  develop
#
# Norm:  _stem Num topics:  20 , Max df:  0.7  Max features:  3000  Alpha:  0.1  Eta:  0.001
#    Topic_0  Topic_1  Topic_10     Topic_11 Topic_12 Topic_13 Topic_14  \
# 0     food     said      said        water     said   forest      new
# 1     said      uae      fund          epa     warm     said    plant
# 2     risk   school    invest       carbon      sea    china    power
# 3    world     year  investor  environment     year     also     said
# 4    would     also     green         said  weather     year   carbon
# 5  plastic  develop      year       global   global       us    would
# 6  student   nation   project       pruitt       al  develop     year
# 7   impact      new     world          use     also     tree   global
# 8   school      use    global         also    world    world      say
# 9     also     plan      also         warm    flood      new      use
#
#     Topic_15 Topic_16 Topic_17     Topic_18  Topic_19   Topic_2  Topic_3  \
# 0       said    water     said  environment      said      said     said
# 1  agreement  nigeria      one         said     china      food      uae
# 2      state    state     like        state    global      year    dubai
# 3     nation  develop    think         also   develop    report  develop
# 4     global     film  student       nation     world  research    world
# 5     action      use      way       action  nigerian       per       al
# 6         un     said     year      sustain     trade    impact      abu
# 7         us     also     make        world   nigeria      cent     also
# 8     commit      say     need      develop    africa      rise   global
# 9       year      one     time        women    nation    global       us
#
#   Topic_4    Topic_5    Topic_6    Topic_7   Topic_8   Topic_9
# 0   human    develop      trump       said     trump      year
# 1    year     nation         us      storm        us       one
# 2   world        law       said     report      said  scotland
# 3    need    sustain      state       warm        mr      time
# 4    also       work  agreement       year    leader      said
# 5    make       need     global     global  european     would
# 6     one       must      would     harvey    summit       per
# 7   earth      india      world    percent       say      cent
# 8     new      build     accord  scientist     state        us
# 9    like  implement     nation        say     world      like
#
# Norm:  _stem Num topics:  20 , Max df:  0.7  Max features:  3000  Alpha:  0.1  Eta:  0.1
#    Topic_0  Topic_1 Topic_10 Topic_11     Topic_12 Topic_13 Topic_14 Topic_15  \
# 0    water   forest    state   invest         said     said     said     said
# 1     food     said   school   market      develop       mr    state    china
# 2   farmer     tree  student    trade       nation    world   impact     year
# 3     also     year     year      new      project     risk     also  develop
# 4  product     also   nation  develop      nigeria   global     plan       eu
# 5     year     fish     said     also        state       go     year    trade
# 6    world    event      one    china         also    would  project   global
# 7     said    water     also      law      sustain    state    water      per
# 8    plant  protect   global    world  environment     also    would     cent
# 9     farm     area      new      one       report   impact   nation       us
#
#   Topic_16  Topic_17 Topic_18   Topic_19  Topic_2  Topic_3    Topic_4 Topic_5  \
# 0     said      said   carbon         us    china  develop       warm    said
# 1      uae   nigeria     year  agreement   global     said       year   trump
# 2     year     world   global      trump    world  sustain     global     one
# 3    world    global     need       said  develop   global  scientist    year
# 4    ocean   develop      gas      state   nation    state    weather    time
# 5      per    invest      per      world     year     need     report   human
# 6     cent      also     plan     global    power     year   research   state
# 7    coral    sector  product     accord    would   nation       rise     say
# 8     reef  nigerian      oil     nation     said     also       like    like
# 9     also      year      new       unit     also     fund      flood      us
#
#   Topic_6      Topic_7    Topic_8   Topic_9
# 0   would        green      trump     trump
# 1   trump         bond      india      said
# 2    said        world         us  scotland
# 3      us         fund      state       new
# 4     one         also       said     power
# 5     per        women     global     obama
# 6    year          one  agreement     state
# 7     say     investor       also     china
# 8    cent          use      would  scottish
# 9    also  environment       year      year
# Norm:  _stem Num topics:  20 , Max df:  0.7  Max features:  3000  Alpha:  0.1  Eta:  0.5
#   Topic_0  Topic_1 Topic_10 Topic_11 Topic_12  Topic_13 Topic_14 Topic_15  \
# 0  global       us      per     said  develop    invest     year     said
# 1   world    world     cent      uae   nation   develop    would    state
# 2   china   global    water    youth    state      fund    green       us
# 3    need     also     said      new     plan      risk     make     coal
# 4   human    would    plant  sustain    water  investor    power     plan
# 5    said    china     year  student  project   sustain     also   nation
# 6     one      new     also  develop     also    sector     said     also
# 7    also     year      use  project     work     green    elect   global
# 8     new  develop     cost     also  sustain       oil      one      new
# 9    food    trade      one       al   region     world       us   action
#
#     Topic_16 Topic_17   Topic_18   Topic_19 Topic_2  Topic_3      Topic_4  \
# 0       warm   carbon      trump      india      al     said         said
# 1       year    power       said         us   saudi     year         like
# 2     global      gas         us      china    pope    world        trump
# 3  scientist      new  agreement       said  arabia     also          say
# 4    weather   global      world      trump    year  million        water
# 5        new     year     global     global   would    would        state
# 6     carbon     need      state      state   world      one          one
# 7       said     said      would  agreement     one     food        storm
# 8        one    world         mr    develop   train   garden  environment
# 9      world      per     accord     nation     tax      say    scientist
#
#      Topic_5  Topic_6   Topic_7 Topic_8   Topic_9
# 0       said    china      said     one      said
# 1         us   global    report    said   develop
# 2      china    world    impact   world   nigeria
# 3      world  develop     state    make     state
# 4     global     said      year    time      year
# 5       bank     year  research    year      also
# 6     region     also      rise    also    nation
# 7      trump   nation      also    like  nigerian
# 8       fuel     make     flood    work     would
# 9  agreement      one     level     get    africa
#
# Norm:  _stem Num topics:  20 , Max df:  0.7  Max features:  3000  Alpha:  0.5  Eta:  0.001
#     Topic_0 Topic_1   Topic_10   Topic_11 Topic_12 Topic_13   Topic_14  \
# 0      said   water      trump    develop     said    water       said
# 1   student    year         us     nation    china      per         us
# 2     state   earth  agreement      power   region      use      trump
# 3  standard     per       said       said  develop    world  agreement
# 4      year    cent     global        law    saudi   forest     global
# 5      also     one      world    nuclear      per    human       year
# 6       new    also      state  agreement     cent   global     report
# 7    global  nation      would        new     year     lake      would
# 8      make    book         mr      world   global     cent     accord
# 9      like     use        new    project      new     also       unit
#
#       Topic_15  Topic_16 Topic_17 Topic_18 Topic_19  Topic_2 Topic_3 Topic_4  \
# 0       nation      said     food     year     said     said    said   trump
# 1      develop      year   farmer    world    state   global   water   state
# 2      nigeria    report     said       us    trump     year   state    said
# 3        state    global  product   global     also      ice    year    time
# 4       global      warm     usda     warm       us     warm   flood     one
# 5         said       sea    world     also    dubai    world    also   would
# 6      sustain      rise  develop     said    india     also  farmer    like
# 7         plan  research     year    model    would    state    plan    year
# 8        world     level    water     need  develop   alaska    like    warm
# 9  environment      also     also    would    world  develop    make     say
#
#     Topic_5  Topic_6    Topic_7   Topic_8      Topic_9
# 0      said     said       said      said         said
# 1    invest    china      world   nigeria       carbon
# 2      fund   global       year     world         year
# 3   project     also   european    africa        world
# 4      also    world     global   develop         risk
# 5      year     year        one   african          say
# 6  investor       us        new  nigerian       global
# 7   develop      one       meet      also  environment
# 8     green   nation  agreement    global         need
# 9    global  develop     target     state        level
#
# Norm:  _stem Num topics:  20 , Max df:  0.7  Max features:  3000  Alpha:  0.5  Eta:  0.1
#     Topic_0 Topic_1 Topic_10  Topic_11  Topic_12 Topic_13   Topic_14 Topic_15  \
# 0      said   state  develop      said      said     said       said  develop
# 1    farmer    said   nation   nigeria     state    green    develop   global
# 2      food    year     said    nation      also      per     nation      new
# 3      also  report     work  nigerian    report  project      would    china
# 4      year   human     also     world      year     cent  agreement     said
# 5   product     say     plan   develop     world     year       plan    build
# 6    forest   would    world   sustain      plan  develop      world   nation
# 7  research    time    state    global  investor     fund     action    world
# 8      farm     one    water      also    global   invest       year     also
# 9       use    like      new     would      risk     also       need    state
#
#     Topic_16 Topic_17 Topic_18  Topic_19 Topic_2    Topic_3 Topic_4  Topic_5  \
# 0       said    water     said  scotland   china      trump   world  develop
# 1       warm  develop     need    global      us       said     oil     said
# 2       year     said     fish       new    year         us      us       al
# 3     global    women  develop      year  global  agreement    said    dhabi
# 4      flood    state    coral  scottish   world      state    year      abu
# 5      storm     also      say      said     new         mr    fuel   nation
# 6  scientist  project     year     world   state      would   would      uae
# 7    weather     need   global       per    said      world    also     year
# 8        sea   sector    could    target  nation     global  global      one
# 9       rise      law      one      also  report     accord     one   global
#
#     Topic_6 Topic_7      Topic_8 Topic_9
# 0      said    said  environment    said
# 1     water   india           us   china
# 2     state    year        trump  global
# 3       use      us       carbon   india
# 4  research   world        power   world
# 5      also    also         also  nation
# 6       one  global        world    year
# 7   develop   would        state     new
# 8      usda   china          new    need
# 9      crop  nation       global    also
#
# Norm:  _stem Num topics:  20 , Max df:  0.7  Max features:  3000  Alpha:  0.5  Eta:  0.5
#   Topic_0  Topic_1 Topic_10    Topic_11   Topic_12   Topic_13  Topic_14  \
# 0    food     said    trump        said      trump       said      said
# 1    said     year     said       would         us     carbon      year
# 2    also   global   global      school     global       also      warm
# 3  nation    world    world       trump  agreement       warm    global
# 4      us  develop    china      global      state       year    forest
# 5   world      new       us        time       said      state       use
# 6     one      one   summit      nation       warm  scientist      also
# 7    work    china    state  republican      world        one      land
# 8    year   school     year        like     nation     global  research
# 9   state  student     also          us     accord     nation       say
#
#   Topic_15   Topic_16 Topic_17 Topic_18   Topic_19    Topic_2 Topic_3 Topic_4  \
# 0     said    develop     said     said      water      trump  global   water
# 1    state       said   global  develop       year         us   world   world
# 2     like      india    world    china       said       said      us    coal
# 3   global      world     also   farmer      flood      would   china   power
# 4   nation      women    india  product        sea  agreement   trump     new
# 5   report       also     year     also       warm        say    said    fuel
# 6     rise     nation    would      new  scientist        one   trade    said
# 7    trump       year     make     year        one       time      eu     gas
# 8       us  agreement   impact      per       time       also  leader    year
# 9    level         us      one   market      level       year     one  carbon
#
#   Topic_5   Topic_6    Topic_7  Topic_8      Topic_9
# 0    said      risk       said     said      develop
# 1      mr    invest    nigeria  project      nigeria
# 2    year      said     global    state      sustain
# 3   would  investor      china     fund         said
# 4   state      also      state  develop  environment
# 5   could      need     nation   nation          uae
# 6     per     world      world   impact       nation
# 7    need      year  agreement     also         year
# 8   world    global         un     plan         work
# 9  report       per       also    green         also

# %%
num_topics = [5,7]
max_dfs = [0.5]
max_features = [1000, 3000]
norm_type = [ '_stem']

alphas = [ 0.001, 0.1, 0.5]
etas = [0.001, 0.1, 0.5]

# %%
topic_loop(news_df, num_topics, max_dfs, max_features, norm_type, alphas, etas)
# Out:
# /home/sunjoo/.local/lib/python3.6/site-packages/gensim/models/ldamodel.py:802: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  1000  Alpha:  0.001  Eta:  0.001
#      Topic_0   Topic_1  Topic_2    Topic_3    Topic_4
# 0    develop      year     year      trump     nation
# 1      india  research      per         us     carbon
# 2      china    impact     need      state       year
# 3         us   develop     cent        say    develop
# 4       year    region  develop       year         us
# 5      state     water    water     nation  agreement
# 6      water    effect      use       time      state
# 7  agreement      area     plan       like       fund
# 8     nation     state   report       make      green
# 9      trump      rise   nation  agreement     report
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  1000  Alpha:  0.001  Eta:  0.1
#    Topic_0    Topic_1    Topic_2    Topic_3      Topic_4
# 0    china       year      trump      trump        state
# 1      per       like         us         us       nation
# 2  develop        say    develop      water         year
# 3     cent       time  agreement      state           us
# 4   nation      could     nation  agreement        trump
# 5     year  scientist       year    develop         need
# 6    power      flood         mr       year       report
# 7     plan    weather      state    project       action
# 8       us      water      china        use  environment
# 9   carbon        use     leader     accord         make
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  1000  Alpha:  0.001  Eta:  0.5
#    Topic_0      Topic_1    Topic_2  Topic_3    Topic_4
# 0  develop        china         us     year      trump
# 1     need       nation      state  weather         us
# 2   nation        trump      water    state     carbon
# 3     work           us       year   report      state
# 4     year      develop  scientist     like  agreement
# 5    state        state   research    flood       year
# 6  project    agreement     impact     time      power
# 7    green       action       like   nation        say
# 8     fund         year     report     make     accord
# 9  support  environment      trump    level         mr
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  1000  Alpha:  0.1  Eta:  0.001
#      Topic_0 Topic_1  Topic_2 Topic_3  Topic_4
# 0      trump    year    power    year  develop
# 1         us  report  develop   water    china
# 2  agreement   state   nation  impact   nation
# 3      state  carbon     year   state     year
# 4     accord     per     work    need  nigeria
# 5     nation     say       mr   flood  project
# 6     action    like     time    like    green
# 7         mr   trump    state     use     plan
# 8       deal  nation      law    rise    state
# 9       plan    cent     make  effect   growth
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  1000  Alpha:  0.1  Eta:  0.1
#      Topic_0    Topic_1      Topic_2 Topic_3  Topic_4
# 0      trump       year        state   trump  develop
# 1         us        say         year    year  nigeria
# 2  agreement       risk  environment      us   nation
# 3      state       food       nation   state     year
# 4      china       like        water   water  support
# 5     nation        use      project  report     fund
# 6       year      state       report    like    state
# 7     accord     impact         need  carbon    green
# 8     carbon  scientist         work    time  project
# 9     leader      human      develop     gas    china
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  1000  Alpha:  0.1  Eta:  0.5
#    Topic_0    Topic_1  Topic_2    Topic_3  Topic_4
# 0    water      trump       us      state  develop
# 1     year         us     year       plan     year
# 2    state       year    green     nation     work
# 3   report     nation      per     action  nigeria
# 4    flood       like   carbon      power    state
# 5  weather  scientist   nation      trump   nation
# 6   impact        say    china         us    china
# 7     like  agreement  develop       need       us
# 8    could       time     cent    develop     need
# 9    storm      state    trump  agreement   africa
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  1000  Alpha:  0.5  Eta:  0.001
#      Topic_0  Topic_1      Topic_2 Topic_3    Topic_4
# 0     report    water      develop      us      trump
# 1       year     year       nation   power       year
# 2   research    state         year   trump         us
# 3      state      per      nigeria   china      state
# 4     impact    flood      project   state  agreement
# 5  scientist  develop  environment    year        say
# 6       rise     cent         food     oil     nation
# 7     nation    india           us     per       time
# 8       like     work         fund    coal       like
# 9        sea     need         need    time     carbon
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  1000  Alpha:  0.5  Eta:  0.1
#    Topic_0    Topic_1    Topic_2    Topic_3      Topic_4
# 0     year    develop      trump      trump         year
# 1    water      china         us      state       nation
# 2   report         us  agreement  scientist      develop
# 3    state      state      state       like      project
# 4      say     nation        per     nation        water
# 5     risk      trump     carbon       time          use
# 6     like       plan       cent         us        state
# 7  weather  agreement       year       make  environment
# 8   impact       work     nation       year        green
# 9     time     leader     accord     accord         need
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  1000  Alpha:  0.5  Eta:  0.5
#      Topic_0  Topic_1  Topic_2    Topic_3 Topic_4
# 0      trump    china  develop       year    year
# 1         us  develop     plan      state   water
# 2  agreement     year   nation  scientist     per
# 3      state   nation    state   research    cent
# 4       year    state   action        say  report
# 5     accord   region   carbon     impact    like
# 6       make     need     need      level   trump
# 7       time    trade  project     nation     say
# 8     nation   africa     work       like   state
# 9       even       us    green    weather   could
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  3000  Alpha:  0.001  Eta:  0.001
#      Topic_0  Topic_1  Topic_2    Topic_3  Topic_4
# 0         us     year     year      trump  develop
# 1       year    human    water         us   nation
# 2  agreement   report   report      state     year
# 3      china    state      per  agreement    state
# 4      trump   nation   impact        say  nigeria
# 5      state     warm     warm     nation  sustain
# 6    develop  percent    flood       year     need
# 7     nation    china  weather       like    china
# 8      trade   action      say       time     plan
# 9     commit     make     cent       make     work
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  3000  Alpha:  0.001  Eta:  0.1
#      Topic_0    Topic_1  Topic_2  Topic_3    Topic_4
# 0      state       year    water  develop      trump
# 1      trump       warm     year     year         us
# 2         us       like  develop   nation        say
# 3       year      state    state  sustain      state
# 4         mr     nation    flood     need     report
# 5     accord       time    china     food       year
# 6        per     carbon     work  project     nation
# 7  agreement  scientist       us   farmer  agreement
# 8     nation      china     make    water       time
# 9       cent       rise  weather     fund       like
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  3000  Alpha:  0.001  Eta:  0.5
#      Topic_0 Topic_1  Topic_2    Topic_3    Topic_4
# 0      trump    year  develop      china       year
# 1         us     per   nation         us       warm
# 2      state   state  nigeria    develop       like
# 3  agreement    cent  sustain  agreement      water
# 4     nation  carbon     work      state     impact
# 5        say    plan     need     nation  scientist
# 6       year  nation   region     invest       time
# 7     accord  forest     year      green     report
# 8     report     say    state       year    weather
# 9         mr    warm  project     commit       need
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  3000  Alpha:  0.1  Eta:  0.001
#    Topic_0  Topic_1  Topic_2    Topic_3    Topic_4
# 0     year     year    trump       year  agreement
# 1  develop     risk    state      trump         us
# 2   nation   carbon   nation      state     invest
# 3  nigeria     need       us      water    develop
# 4       us  develop  develop         us      china
# 5     time     like   accord     report       year
# 6     make      use     year       warm       need
# 7     work     make   carbon        say     action
# 8     need   impact   report       like      trump
# 9   health     work    power  scientist         mr
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  3000  Alpha:  0.1  Eta:  0.1
#    Topic_0    Topic_1    Topic_2  Topic_3  Topic_4
# 0  nigeria      trump       year    trump    water
# 1       mr         us      state       us  develop
# 2    china       year  scientist    state     year
# 3   nation  agreement     impact   nation     food
# 4  develop      state       rise    china     need
# 5       us     carbon       warm  develop  project
# 6     year       warm      flood     year  sustain
# 7   report     nation      level   leader      use
# 8    state        say       like      per   nation
# 9   accord     accord     nation     cent      per
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  3000  Alpha:  0.1  Eta:  0.5
#      Topic_0  Topic_1    Topic_2  Topic_3  Topic_4
# 0       year    water      trump  develop    state
# 1       warm     year         us       us   nation
# 2       time  develop  agreement     year  develop
# 3       like   report      state   nation       us
# 4  scientist   impact     nation    china    trump
# 5        say    state     accord   invest     need
# 6      human     food     action    state  nigeria
# 7       rise      per       year    green     work
# 8     carbon     need         mr  sustain     make
# 9        use   farmer        gas     need   leader
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  3000  Alpha:  0.5  Eta:  0.001
#    Topic_0  Topic_1    Topic_2 Topic_3  Topic_4
# 0    china    state      trump   water  develop
# 1  develop  student         us    year   nation
# 2   invest     year       year      us    state
# 3     year     need      state  report  nigeria
# 4       us   school       warm   state     need
# 5   nation   forest        say     per  sustain
# 6    power      say       time  impact     plan
# 7  project     work     nation    food    green
# 8     need    plant  agreement    warm     year
# 9     work     make       like  nation     work
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  3000  Alpha:  0.5  Eta:  0.1
#        Topic_0 Topic_1  Topic_2    Topic_3  Topic_4
# 0        water   state      per      trump     year
# 1      develop    year     cent         us  develop
# 2       nation    need     year       year   nation
# 3        state  nation   invest      state     need
# 4         plan    warm  develop  agreement    power
# 5  environment    like   report       warm       us
# 6         year  carbon     fund     nation     work
# 7       report  action    green        say    state
# 8       effect   could   carbon       like    china
# 9       impact     say   nation       time     make
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  3000  Alpha:  0.5  Eta:  0.5
#        Topic_0   Topic_1    Topic_2    Topic_3      Topic_4
# 0          say     water      trump    develop         year
# 1         year      year       warm         us         need
# 2        china     state         us      state         make
# 3        state       per       year     nation      project
# 4       nation   develop       like      trump      develop
# 5  environment     flood     report  agreement         time
# 6         work      cent      state     invest      student
# 7      develop      plan  scientist       year       school
# 8       impact  research     carbon       fund         plan
# 9       forest      need     nation       need  environment
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  1000  Alpha:  0.001  Eta:  0.001
#    Topic_0    Topic_1    Topic_2  Topic_3 Topic_4      Topic_5  Topic_6
# 0  develop      trump       year    water      us        state  develop
# 1    china         us       time     year   india       report   nation
# 2     year  agreement       like      per    year         year  nigeria
# 3    green      state        say     cent   power        human   forest
# 4   nation     nation       make     need  carbon    scientist    state
# 5  support         mr      storm     food     say       impact     year
# 6  project     accord       take      use    coal  environment      per
# 7     work       year  scientist  project     per     research   action
# 8    trade     leader      flood   impact   trump       health     plan
# 9   region      china      state    could  nation        level     work
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  1000  Alpha:  0.001  Eta:  0.1
#      Topic_0      Topic_1  Topic_2    Topic_3  Topic_4   Topic_5  Topic_6
# 0      trump         year    china       year  develop     state  develop
# 1         us          say   market     report     year     water  nigeria
# 2      state         time      oil      water   carbon   develop   nation
# 3  agreement         like   carbon    weather     need      year     year
# 4     nation        human     year     impact   action     green     need
# 5     accord        state  develop      flood     plan    region     work
# 6         mr       nation      law  scientist   nation      area     make
# 7   american           us    price       like    state   project     must
# 8       year      percent       us       rise     risk  research   africa
# 9     action  environment    trade        per      gas   support    china
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  1000  Alpha:  0.001  Eta:  0.5
#      Topic_0 Topic_1    Topic_2  Topic_3 Topic_4  Topic_5 Topic_6
# 0      trump      us      trump  develop     per     year   state
# 1  scientist   trump         us   nation    cent     time   water
# 2   research    year  agreement  nigeria    year      say  report
# 3       year   state      state     year     gas     risk  impact
# 4      water     say     nation    china   power     like  health
# 5         us    like         mr     need  target    could    year
# 6        say    time     action  project   china     rise  carbon
# 7        sea  nation     accord     work     oil  weather    need
# 8      ocean    make     leader  support  carbon   impact    plan
# 9       time   think       meet    build  report     make  nation
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  1000  Alpha:  0.1  Eta:  0.001
#    Topic_0  Topic_1    Topic_2  Topic_3    Topic_4  Topic_5 Topic_6
# 0       us  develop      trump    water      trump  develop    year
# 1    state      per         us    china      state   nation  carbon
# 2     year  nigeria  agreement     need        say    china   state
# 3    trump     cent         mr     year       year       us   flood
# 4  develop     year      state  develop  scientist     year    like
# 5   nation   nation     accord    india       like     need    risk
# 6    china     food        gas   market     nation     meet   water
# 7    power  project     nation   report       time    india   could
# 8     coal  million     carbon    trade     report    state    need
# 9     time    green     action       eu         us   region  action
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  1000  Alpha:  0.1  Eta:  0.1
#    Topic_0    Topic_1      Topic_2 Topic_3    Topic_4  Topic_5    Topic_6
# 0    state      trump      develop   water      trump    china       year
# 1     plan         us         work    year      state    trump       like
# 2  develop  agreement  environment     per       year       us    weather
# 3   nation      state       nation    cent  scientist     year       time
# 4     need     nation        china      us        say  develop      flood
# 5  nigeria    develop     research     say       time    trade       rise
# 6    green     accord         make    food     nation    state   research
# 7   carbon      india         need    like       work       eu  scientist
# 8   report         mr         year    need     report     meet      storm
# 9     year      china      program    time       make   leader     impact
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  1000  Alpha:  0.1  Eta:  0.5
#      Topic_0  Topic_1  Topic_2  Topic_3      Topic_4   Topic_5    Topic_6
# 0       year     year  develop  develop        state      year      trump
# 1       time   report   forest   nation        water   develop         us
# 2      solar     time    state    china         year      plan      state
# 3     region     like     plan  nigeria       impact      need  agreement
# 4  scientist     risk   africa      per        level    nation     nation
# 5       film  weather   nation     cent  environment       oil     accord
# 6      earth     need     year     year     research    action        say
# 7      china   carbon    china     need          sea  scotland       year
# 8     accord      say  african    power         rise     water         mr
# 9        air     make     area     work        flood     green     action
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  1000  Alpha:  0.5  Eta:  0.001
#     Topic_0 Topic_1    Topic_2    Topic_3  Topic_4 Topic_5  Topic_6
# 0      year   trump       time      trump  develop    year   nation
# 1    impact      us       like      state     year   water  develop
# 2     state    year  scientist         us       us  carbon     year
# 3     level  nation       year  agreement    india    need      per
# 4   weather  report      state    develop   nation     say     cent
# 5    report   state    percent     nation       al   state    china
# 6   project    make       even     accord    state    like     risk
# 7    region    time       food       plan    china    fuel     need
# 8  research      mr     nation     action      uae    make     fund
# 9      rise    work       need       year    dhabi     use    state
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  1000  Alpha:  0.5  Eta:  0.1
#    Topic_0 Topic_1  Topic_2    Topic_3  Topic_4    Topic_5    Topic_6
# 0   nation    year  develop         us     risk      trump       year
# 1  develop  school    state      trump    state         us     report
# 2    water    need   nation  agreement  develop      state      water
# 3     make   china  nigeria     nation   action  agreement        say
# 4     time  carbon   forest      china   carbon       year  scientist
# 5     year    work     food         mr     need     nation      state
# 6     work  impact   africa      india     fund     action       like
# 7    flood     use     plan    develop     year   american       rise
# 8  weather    time     year     accord      gas       like      could
# 9    storm  nation       us       year   nation       make      level
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  1000  Alpha:  0.5  Eta:  0.5
#      Topic_0   Topic_1  Topic_2  Topic_3  Topic_4    Topic_5      Topic_6
# 0      trump      year     year  develop    india         mr        state
# 1         us     state    water   nation     year      green      develop
# 2      state    report      use    local  develop       year  environment
# 3  agreement    nation      per      law    water         us      nigeria
# 4     nation     china  develop      two   report      power       nation
# 5       year       say     time    china       us  agreement         year
# 6       like   develop  weather     work   nation     nation       impact
# 7     action  research   impact    state     fund      state       region
# 8        say       per     like     need    trump       plan         plan
# 9       time    forest    flood     year     make      trump         need
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  3000  Alpha:  0.001  Eta:  0.001
#   Topic_0    Topic_1  Topic_2  Topic_3  Topic_4    Topic_5   Topic_6
# 0   trump      china  develop    water     year   nigerian    invest
# 1      us      trump    state     year    state    support    carbon
# 2     say  agreement   nation  develop     warm     nation      year
# 3    year         us  nigeria   nation    water    develop      risk
# 4   state      state     need     make   report       year  investor
# 5    time     nation     food      per    flood  scientist       per
# 6    like       year  sustain    power  weather      state       gas
# 7   human    develop  product     time     like   research      cent
# 8  nation     accord   forest      use     rise       work     could
# 9  action       unit     year     like    could       need    report
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  3000  Alpha:  0.001  Eta:  0.1
#     Topic_0 Topic_1   Topic_2      Topic_3 Topic_4  Topic_5    Topic_6
# 0     water   power   nigeria      develop    year   impact      trump
# 1      food   trump    nation        state    warm    state         us
# 2      need  carbon     china         year     per   nation  agreement
# 3     state    year     state        china    like     risk      state
# 4       use  report      year      project     say     year     nation
# 5    farmer    time   develop       nation  nation  develop         mr
# 6      year     say       law         plan   state    level     accord
# 7    impact      us  nigerian      sustain    rise     rise     action
# 8   product   state     green         work    time     need     commit
# 9  research    fuel       say  environment   water   report       year
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  3000  Alpha:  0.001  Eta:  0.5
#     Topic_0      Topic_1    Topic_2  Topic_3    Topic_4 Topic_5    Topic_6
# 0     china        water      trump     year       warm    year    develop
# 1        mr      develop      state  product       year  carbon     nation
# 2        us      nigeria         us   farmer  scientist     per       year
# 3    invest      sustain  agreement      per        sea    need  agreement
# 4    nation         work     nation       us      flood     use    support
# 5      year        state     action   report       like   could     commit
# 6  investor         year     report     cent    weather     say       need
# 7    region       nation     accord    power      storm    like      china
# 8    market  environment       time      say     nation    cent      india
# 9     state         food       year     farm     report      us    sustain
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  3000  Alpha:  0.1  Eta:  0.001
#     Topic_0   Topic_1  Topic_2      Topic_3    Topic_4    Topic_5  Topic_6
# 0       per      year     year        water     report      trump     year
# 1      cent    carbon  develop      develop  scientist         us    state
# 2      year    invest  project        trump       warm      state   nation
# 3   product   develop      use        state      trump  agreement     need
# 4     china      need    state         year      state     nation     like
# 5  scottish      fund   nation         work        say      china    flood
# 6   develop     power      uae  environment      water    develop     warm
# 7       say     green     time       region       time     accord  weather
# 8    region       gas     work           us       like       unit     rise
# 9    import  investor  support      sustain       year     leader      per
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  3000  Alpha:  0.1  Eta:  0.1
#   Topic_0  Topic_1    Topic_2    Topic_3  Topic_4      Topic_5    Topic_6
# 0   trump  develop  agreement      trump    water       invest       year
# 1      us    state     nation      state     year        green     report
# 2    year  nigeria    develop       warm    state      develop   research
# 3   state    china         us       year  develop         year        say
# 4    time   nation      state         us   impact         need      water
# 5    like       us      trump        say   forest  environment       like
# 6    work     year      power     carbon  product      project       food
# 7      go  sustain     action  scientist     plan         work        use
# 8  leader     need     commit       time     need       market        per
# 9    make     fund       year       like     area       report  scientist
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  3000  Alpha:  0.1  Eta:  0.5
#   Topic_0    Topic_1 Topic_2  Topic_3  Topic_4    Topic_5    Topic_6
# 0   trump       year    year    water      per    develop         us
# 1      us       warm     per     year     food     nation      trump
# 2   state  scientist  invest     need  product      state  agreement
# 3    year    weather  carbon      say     cent    nigeria      state
# 4     say     report    cent    state     year    sustain     nation
# 5    like      state      us    flood   farmer  agreement     accord
# 6    time     impact     use   forest   market    project      china
# 7  nation      could    risk      use  develop       year    develop
# 8    make       like     say     area     need       fund     action
# 9      mr       rise    time  develop     make       need     carbon
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  3000  Alpha:  0.5  Eta:  0.001
#    Topic_0  Topic_1      Topic_2  Topic_3 Topic_4  Topic_5    Topic_6
# 0       us     year        trump    water    year  develop      state
# 1   nation  weather           us     year    warm     need         us
# 2     year      use        state      per    like     year      china
# 3    state     food    agreement     cent   state  project     nation
# 4     need    event       report  project     say    green      trump
# 5  develop     like         year      use    time    china    develop
# 6   action  develop  environment    plant    rise   nation   nigerian
# 7    trump     warm       accord     need  impact      per  agreement
# 8     like   nation       nation  develop   human   market     leader
# 9     make    water        could   nation  report   invest       meet
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  3000  Alpha:  0.5  Eta:  0.1
#    Topic_0    Topic_1      Topic_2    Topic_3 Topic_4 Topic_5      Topic_6
# 0    water      trump        trump      china    year    year         year
# 1  develop         us        state    develop    like  report      develop
# 2    state  agreement           us      power    time     per       forest
# 3   nation      state         year     nation     say   state       nation
# 4   report       year          say    nigeria   state  nation  environment
# 5     year     accord      develop      green     use    cent      sustain
# 6   impact     nation       invest      state    make   could        water
# 7     plan        say           mr  agreement  carbon   storm         plan
# 8  weather       warm  environment     invest    need    warm         work
# 9    flood       make       report    sustain    live    like       action
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  3000  Alpha:  0.5  Eta:  0.5
#      Topic_0 Topic_1 Topic_2  Topic_3      Topic_4   Topic_5    Topic_6
# 0    develop   water    year     year         year    nation      trump
# 1  agreement    risk     say     warm      develop     state      state
# 2         us      us    like    level       nation   weather         us
# 3      china    year     per   nation        state      year  agreement
# 4      trump  report    need   report         need      food     nation
# 5     nation   state    time     like  environment   develop        say
# 6       plan  impact   water  develop      sustain  research     accord
# 7     action  nation     use   carbon       invest      warm       year
# 8       year    rise    make     rise      project    report       make
# 9    support   flood  farmer    power         make    impact       time

# %%
num_topics = [3]
max_dfs = [0.3, 0.5]
max_features = [1000, 2000, 3000]
norm_type = [ '_stem']

alphas = [ 0.00001, 0.001, 0.1, 0.5]
etas = [0.00001, 0.001, 0.1, 0.5]

# %%
topic_loop(news_df, num_topics, max_dfs, max_features, norm_type, alphas, etas)
# Out:
# /home/sunjoo/.local/lib/python3.6/site-packages/gensim/models/ldamodel.py:802: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  1000  Alpha:  1e-05  Eta:  1e-05
#    Topic_0    Topic_1  Topic_2
# 0  develop       warm      per
# 1   nation     nation     cent
# 2    china     impact      say
# 3     plan  scientist       mr
# 4    water      human   nation
# 5      use     report  develop
# 6   region   research    power
# 7  project        say     plan
# 8    power      level   report
# 9    build       rise   accord
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  1000  Alpha:  1e-05  Eta:  0.001
#      Topic_0  Topic_1 Topic_2
# 0     nation  develop  report
# 1       warm   nation   water
# 2    develop   accord     use
# 3        say    china     say
# 4  scientist     plan  impact
# 5      level  support    risk
# 6       rise    power    warm
# 7      human   leader   power
# 8   research     meet  nation
# 9        per     work  public
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  1000  Alpha:  1e-05  Eta:  0.1
#    Topic_0  Topic_1    Topic_2
# 0   nation    india      water
# 1  develop  develop     report
# 2   accord  project       warm
# 3     plan     work  scientist
# 4      say      say     impact
# 5    china   impact    weather
# 6       mr    green   research
# 7  support   nation      flood
# 8    power    china        use
# 9   leader    power        per
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  1000  Alpha:  1e-05  Eta:  0.5
#   Topic_0  Topic_1  Topic_2
# 0  nation  develop    water
# 1  report   nation      say
# 2     per    china     work
# 3    warm    india     warm
# 4   power  nigeria      use
# 5    cent     work  weather
# 6     gas   accord    human
# 7  accord  support       go
# 8      mr  project   nation
# 9  impact      use   impact
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  1000  Alpha:  0.001  Eta:  1e-05
#    Topic_0   Topic_1    Topic_2
# 0   report   develop        say
# 1   nation    nation       warm
# 2       mr  research     nation
# 3     risk     china      human
# 4    china     water        use
# 5   accord      work      water
# 6  develop   project  scientist
# 7     meet      plan     impact
# 8     plan    region     report
# 9      gas   support      power
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  1000  Alpha:  0.001  Eta:  0.001
#      Topic_0  Topic_1  Topic_2
# 0      water   nation      say
# 1       warm  develop   report
# 2     impact    china     work
# 3     nation   accord     risk
# 4     report  nigeria       go
# 5  scientist    power   nation
# 6   research      gas     plan
# 7    weather     work      get
# 8      flood  support  support
# 9        per    green     fund
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  1000  Alpha:  0.001  Eta:  0.1
#    Topic_0  Topic_1  Topic_2
# 0  develop   nation    water
# 1     warm      say  develop
# 2   leader   report   nation
# 3   nation   accord    flood
# 4     work      per  weather
# 5     meet    power   impact
# 6  support     plan    china
# 7    china  develop   region
# 8      use      use     warm
# 9      oil     work    level
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  1000  Alpha:  0.001  Eta:  0.5
#    Topic_0    Topic_1  Topic_2
# 0     plan      water   nation
# 1   nation       warm  develop
# 2    power     report      per
# 3  develop     nation     food
# 4     fund        say     cent
# 5   accord    weather    water
# 6      gas       rise   report
# 7      say        use     work
# 8  support  scientist   region
# 9     warm    develop  million
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  1000  Alpha:  0.1  Eta:  1e-05
#     Topic_0  Topic_1    Topic_2
# 0    nation  develop       warm
# 1   develop    water        say
# 2    impact   nation     nation
# 3     flood  nigeria     report
# 4    report  project     accord
# 5      plan     work  scientist
# 6   weather    power      level
# 7  research  support      human
# 8     water     food       rise
# 9    health      per        use
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  1000  Alpha:  0.1  Eta:  0.001
#     Topic_0  Topic_1    Topic_2
# 0     water  develop     nation
# 1   develop       mr        say
# 2     flood      per       warm
# 3    impact   nation     report
# 4     china   accord  scientist
# 5    nation    india       work
# 6       use  project      human
# 7  research     fund    support
# 8       sea     food     accord
# 9      rise     cent       plan
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  1000  Alpha:  0.1  Eta:  0.1
#    Topic_0    Topic_1  Topic_2
# 0   report       warm   nation
# 1   nation        say    water
# 2  develop     nation  develop
# 3  weather    develop      per
# 4     food      power    green
# 5     plan      china    china
# 6     risk  scientist  nigeria
# 7   impact         mr      say
# 8    water      level   accord
# 9    flood        gas   health
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  1000  Alpha:  0.1  Eta:  0.5
#     Topic_0    Topic_1  Topic_2
# 0   develop     report  develop
# 1    nation        say   nation
# 2       use       warm    china
# 3  research      water  support
# 4      work     impact   leader
# 5   nigeria     nation    power
# 6   project       rise     meet
# 7    impact      level     plan
# 8       per  scientist     fund
# 9      food    weather    india
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  1000  Alpha:  0.5  Eta:  1e-05
#    Topic_0 Topic_1  Topic_2
# 0  develop  nation    water
# 1      per  report  develop
# 2   nation     say   nation
# 3    green    warm   impact
# 4     cent  accord     risk
# 5  nigeria   power     work
# 6      use      mr    flood
# 7   accord   human    level
# 8  support    rise     warm
# 9    china      go  project
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  1000  Alpha:  0.5  Eta:  0.001
#    Topic_0  Topic_1    Topic_2
# 0   nation    china       warm
# 1  develop    power     report
# 2    water  develop        say
# 3   impact      per     nation
# 4     plan   nation     accord
# 5   effect     coal  scientist
# 6    level      oil       work
# 7     rise     cent   research
# 8      say      gas         mr
# 9     warm     meet      human
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  1000  Alpha:  0.5  Eta:  0.1
#    Topic_0   Topic_1    Topic_2
# 0    china   develop       warm
# 1     plan    nation     report
# 2   nation      work      water
# 3    power   nigeria        say
# 4  develop   project     nation
# 5       mr  research  scientist
# 6  support   support       rise
# 7   leader    report      level
# 8    india    impact     impact
# 9      say      fund      human
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  1000  Alpha:  0.5  Eta:  0.5
#    Topic_0  Topic_1    Topic_2
# 0    china  develop       warm
# 1   nation   nation        say
# 2  develop    power      water
# 3   accord     plan     nation
# 4       mr     fund     report
# 5     meet      per  scientist
# 6   leader      gas     impact
# 7     work      use   research
# 8     food   report      human
# 9    trade  project      level
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  2000  Alpha:  1e-05  Eta:  1e-05
#    Topic_0  Topic_1    Topic_2
# 0  develop  develop       warm
# 1     food   nation        say
# 2  product    china     report
# 3   nation   invest  scientist
# 4   farmer     plan      water
# 5      use     work     nation
# 6   report   accord      human
# 7  nigeria  support     impact
# 8      per    power       rise
# 9  million     meet      level
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  2000  Alpha:  1e-05  Eta:  0.001
#    Topic_0    Topic_1  Topic_2
# 0  develop      water   nation
# 1   nation       warm     work
# 2   accord     report      say
# 3     fund     impact    china
# 4     plan        say  develop
# 5    china     nation    power
# 6    green       rise       go
# 7   invest        use      way
# 8  support  scientist     come
# 9      per   research     want
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  2000  Alpha:  1e-05  Eta:  0.1
#    Topic_0    Topic_1  Topic_2
# 0  develop       warm   nation
# 1   nation        say  develop
# 2     plan  scientist    china
# 3   report     impact       mr
# 4    india      water   accord
# 5    water        use    power
# 6  support     report     meet
# 7     food      human   leader
# 8   accord   research  nigeria
# 9      per     nation    green
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  2000  Alpha:  1e-05  Eta:  0.5
#    Topic_0  Topic_1    Topic_2
# 0   nation  develop       warm
# 1  develop   invest        say
# 2      use   nation     report
# 3     food    water     nation
# 4   report    china       rise
# 5    water  project  scientist
# 6    human     fund      level
# 7   impact    power       risk
# 8   accord     plan    weather
# 9     work   accord    develop
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  2000  Alpha:  0.001  Eta:  1e-05
#      Topic_0  Topic_1  Topic_2
# 0       warm  develop   nation
# 1     nation      say  develop
# 2     report     work    china
# 3  scientist     plan      per
# 4       risk      use   accord
# 5      human   nation       mr
# 6      water     warm   report
# 7        say     come     cent
# 8       rise   forest  nigeria
# 9      level    build    power
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  2000  Alpha:  0.001  Eta:  0.001
#    Topic_0    Topic_1  Topic_2
# 0   nation     nation       mr
# 1    china     report   invest
# 2  develop       warm  develop
# 3    water        say      oil
# 4   accord    develop  student
# 5  nigeria     impact   school
# 6  support  scientist    water
# 7   leader      human     work
# 8     work        use  project
# 9     meet        per   africa
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  2000  Alpha:  0.001  Eta:  0.1
#    Topic_0    Topic_1    Topic_2
# 0  develop     report    develop
# 1   nation     nation       warm
# 2    china      water     nation
# 3   invest        per   research
# 4   accord        say    weather
# 5  support       warm     impact
# 6     work        use    project
# 7      say  scientist       plan
# 8  nigeria       cent      water
# 9   leader     impact  scientist
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  2000  Alpha:  0.001  Eta:  0.5
#    Topic_0  Topic_1    Topic_2
# 0    water   nation     report
# 1  weather  develop       warm
# 2    flood    china        per
# 3     risk     work     nation
# 4   impact  support        say
# 5  develop      say      water
# 6     plan    power        use
# 7    level   accord       cent
# 8     rise   leader  scientist
# 9   invest      way     accord
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  2000  Alpha:  0.1  Eta:  1e-05
#    Topic_0    Topic_1  Topic_2
# 0   nation       warm  develop
# 1  develop        say    water
# 2     plan     report      per
# 3     risk     nation   nation
# 4     fund  scientist    power
# 5  support      human  product
# 6      use   research     food
# 7     work     impact   invest
# 8      way    weather    china
# 9   accord     accord      use
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  2000  Alpha:  0.1  Eta:  0.001
#    Topic_0    Topic_1  Topic_2
# 0    power       warm  develop
# 1       mr        say   nation
# 2    water     report     plan
# 3   nation  scientist      use
# 4   accord     impact  project
# 5  develop     nation  product
# 6      say      human   invest
# 7    china       rise    china
# 8     plan   research  support
# 9  support    weather     work
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  2000  Alpha:  0.1  Eta:  0.1
#    Topic_0  Topic_1    Topic_2
# 0   nation    water        say
# 1    china  develop       warm
# 2  develop   report      human
# 3   accord   nation  scientist
# 4  support   impact     nation
# 5     meet     warm        use
# 6    power     plan         go
# 7   leader    flood       work
# 8   invest    level        get
# 9     work   region      level
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  2000  Alpha:  0.1  Eta:  0.5
#    Topic_0    Topic_1  Topic_2
# 0  develop       warm   nation
# 1   nation  scientist      say
# 2    water    weather   accord
# 3   report      human       mr
# 4     food        say     work
# 5  project     report     plan
# 6   impact     nation  support
# 7   region        use   invest
# 8    level        per  develop
# 9    china   research    green
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  2000  Alpha:  0.5  Eta:  1e-05
#    Topic_0  Topic_1    Topic_2
# 0   report   nation      water
# 1      say  develop     nation
# 2     risk     warm    develop
# 3      per    power       food
# 4     warm   accord       work
# 5   impact    china   research
# 6  develop       mr  scientist
# 7   nation   report        use
# 8     cent  support     effect
# 9     rise    human    support
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  2000  Alpha:  0.5  Eta:  0.001
#    Topic_0    Topic_1  Topic_2
# 0    water        say  develop
# 1  develop  scientist   nation
# 2   nation     nation    china
# 3      use       warm   invest
# 4   impact     report      per
# 5     warm      human    power
# 6  weather     accord   accord
# 7     plan       work     fund
# 8   effect   research  nigeria
# 9     area       rise  project
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  2000  Alpha:  0.5  Eta:  0.1
#    Topic_0    Topic_1   Topic_2
# 0   nation       warm   develop
# 1   report      water    nation
# 2     plan        use      work
# 3   accord        say   nigeria
# 4    china        per  research
# 5       mr    weather   support
# 6      say     nation      food
# 7  develop  scientist   product
# 8    power     impact       say
# 9    level    develop      help
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  2000  Alpha:  0.5  Eta:  0.5
#    Topic_0  Topic_1   Topic_2
# 0   nation    water     china
# 1   report  develop    nation
# 2   accord      say      work
# 3  develop   nation  research
# 4     warm   impact   develop
# 5      per     warm     india
# 6      say     plan    farmer
# 7  support  project    region
# 8   invest      use       use
# 9     risk     work     power
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  3000  Alpha:  1e-05  Eta:  1e-05
#      Topic_0  Topic_1  Topic_2
# 0       warm  develop   nation
# 1  scientist   nation    water
# 2        say  nigeria  develop
# 3     nation    china      use
# 4   research  sustain     plan
# 5     report   leader      per
# 6      human   accord   report
# 7       work     unit  project
# 8     impact     work    power
# 9       rise      per      gas
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  3000  Alpha:  1e-05  Eta:  0.001
#    Topic_0    Topic_1  Topic_2
# 0   accord      water  develop
# 1       mr       warm   nation
# 2    china     report  sustain
# 3    power     nation  nigeria
# 4      say        say    china
# 5   nation     impact     plan
# 6     work  scientist  project
# 7   invest       rise    green
# 8  support      human  support
# 9   leader      level   import
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  3000  Alpha:  1e-05  Eta:  0.1
#    Topic_0    Topic_1  Topic_2
# 0   nation       warm  develop
# 1    power     nation   nation
# 2      per      water     plan
# 3    china        say     work
# 4   invest  scientist  sustain
# 5   report     impact      use
# 6  develop     report  project
# 7     cent    develop  nigeria
# 8   accord     accord   impact
# 9      say       rise    water
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  3000  Alpha:  1e-05  Eta:  0.5
#    Topic_0    Topic_1  Topic_2
# 0  develop      water   nation
# 1  nigeria       warm  develop
# 2   nation     report    china
# 3    china        say   accord
# 4    india  scientist   invest
# 5    green     impact     work
# 6  sustain     nation   commit
# 7     meet        use     unit
# 8  support       rise     plan
# 9   leader      human  support
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  3000  Alpha:  0.001  Eta:  1e-05
#    Topic_0  Topic_1    Topic_2
# 0   nation  develop       warm
# 1  develop   nation     report
# 2   accord    china        say
# 3    power  nigeria  scientist
# 4       mr  sustain      water
# 5   invest    water     nation
# 6     fund     work        use
# 7   commit  product      human
# 8     plan  project     impact
# 9      gas  support   research
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  3000  Alpha:  0.001  Eta:  0.001
#    Topic_0    Topic_1  Topic_2
# 0  develop       warm      per
# 1   nation        say     cent
# 2     work     report   nation
# 3     unit      human    power
# 4    china  scientist  develop
# 5   accord     nation   report
# 6     plan      water   impact
# 7  sustain         go   invest
# 8      use        use    water
# 9  nigeria    weather    india
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  3000  Alpha:  0.001  Eta:  0.1
#    Topic_0    Topic_1  Topic_2
# 0  develop       warm    water
# 1   nation        say  develop
# 2    china     report   nation
# 3       mr  scientist  project
# 4  nigeria      human   invest
# 5  support       rise    green
# 6     meet     nation     work
# 7     unit   research     plan
# 8   accord     impact      use
# 9     plan        use     fund
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  3000  Alpha:  0.001  Eta:  0.5
#      Topic_0  Topic_1 Topic_2
# 0       warm  develop  nation
# 1     report   nation  accord
# 2  scientist   invest    unit
# 3        say  sustain      mr
# 4     nation    china  commit
# 5      water  nigeria   china
# 6      human    water    meet
# 7   research  support  leader
# 8     impact   impact   power
# 9      level     plan    work
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  3000  Alpha:  0.1  Eta:  1e-05
#    Topic_0  Topic_1    Topic_2
# 0   nation  develop       warm
# 1   accord    water     report
# 2  develop   nation        say
# 3    power      per     nation
# 4    china    china  scientist
# 5  support     plan       rise
# 6   invest      use      level
# 7     work  sustain      human
# 8   commit  product     impact
# 9       mr   impact    weather
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  3000  Alpha:  0.1  Eta:  0.001
#     Topic_0    Topic_1  Topic_2
# 0   develop       warm   invest
# 1    nation     report  develop
# 2     china     nation     plan
# 3   nigeria        say   accord
# 4   sustain      water    green
# 5      work  scientist     fund
# 6   project      human   nation
# 7  research       rise      say
# 8    impact     impact      per
# 9   support      level    india
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  3000  Alpha:  0.1  Eta:  0.1
#    Topic_0    Topic_1  Topic_2
# 0  develop       warm   nation
# 1   nation        say  develop
# 2    water  scientist      per
# 3  sustain      human    power
# 4    china     nation   accord
# 5     risk     report     cent
# 6      use    weather     plan
# 7  nigeria         go   commit
# 8   report        get     work
# 9   impact       come  project
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  3000  Alpha:  0.1  Eta:  0.5
#    Topic_0  Topic_1    Topic_2
# 0  develop   nation      human
# 1    water    power       work
# 2   nation      say        say
# 3   impact   report  scientist
# 4     food  develop    develop
# 5      use     plan     nation
# 6     warm     warm      china
# 7   region   accord      think
# 8   report     fund     report
# 9      per      gas       warm
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  3000  Alpha:  0.5  Eta:  1e-05
#   Topic_0  Topic_1    Topic_2
# 0   china  develop       warm
# 1  nation   nation     nation
# 2      mr     work        say
# 3   power  project     report
# 4  accord  sustain  scientist
# 5  report   invest      water
# 6     gas     plan     impact
# 7  commit    water      human
# 8   level     fund        use
# 9  invest      per     accord
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  3000  Alpha:  0.5  Eta:  0.001
#    Topic_0    Topic_1  Topic_2
# 0  develop       warm     work
# 1   nation     report      use
# 2    china        say  develop
# 3  sustain     nation   nation
# 4    water     accord     fund
# 5    power  scientist  project
# 6  nigeria       rise     help
# 7     plan      level   impact
# 8      per   research    water
# 9   invest     impact    local
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  3000  Alpha:  0.5  Eta:  0.1
#    Topic_0   Topic_1  Topic_2
# 0    water   develop   nation
# 1     warm    nation    power
# 2   nation      risk      say
# 3   report  research    china
# 4    level    invest   accord
# 5      say    report  develop
# 6  develop       use     work
# 7   impact      warm  support
# 8     rise    impact      use
# 9     plan   nigeria      per
#
# Norm:  _stem Num topics:  3 , Max df:  0.3  Max features:  3000  Alpha:  0.5  Eta:  0.5
#    Topic_0    Topic_1  Topic_2
# 0    water       warm   nation
# 1  develop     report  develop
# 2      per        say    china
# 3    flood  scientist   invest
# 4   nation      human  nigeria
# 5  project     nation   accord
# 6  weather     accord    green
# 7      say     impact    power
# 8   impact      level  support
# 9      use        use   commit
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  1000  Alpha:  1e-05  Eta:  1e-05
#      Topic_0    Topic_1  Topic_2
# 0       year      trump    china
# 1      state         us     year
# 2     report      state  develop
# 3     carbon  agreement     work
# 4       like     nation     need
# 5     impact       year       us
# 6     nation    develop   nation
# 7   research       make     time
# 8  scientist       need    power
# 9      could    support   market
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  1000  Alpha:  1e-05  Eta:  0.001
#      Topic_0   Topic_1      Topic_2
# 0      trump      year           us
# 1      state     water        trump
# 2     nation       use         year
# 3         us      time        state
# 4      china  research       nation
# 5    develop    nation          say
# 6  agreement      like      develop
# 7       plan    carbon         like
# 8     accord    report       action
# 9       year     could  environment
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  1000  Alpha:  1e-05  Eta:  0.1
#   Topic_0  Topic_1    Topic_2
# 0   state     year      trump
# 1      us  develop         us
# 2    year      per      state
# 3   trump   nation      china
# 4  nation    water    develop
# 5  report     need       year
# 6     say     cent  agreement
# 7    like      use     nation
# 8    make  project      india
# 9  action     food     leader
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  1000  Alpha:  1e-05  Eta:  0.5
#   Topic_0    Topic_1      Topic_2
# 0    year      trump       nation
# 1    like         us      develop
# 2     say      state        water
# 3    time  agreement        state
# 4  report       year      project
# 5    need     nation         year
# 6    make    develop           us
# 7     use     action        china
# 8   state       plan        green
# 9   could     accord  environment
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  1000  Alpha:  0.001  Eta:  1e-05
#      Topic_0 Topic_1  Topic_2
# 0      trump    year     year
# 1      state  report    china
# 2         us    like  develop
# 3  agreement   water       us
# 4     nation    time     need
# 5       year     say   nation
# 6     accord   state   carbon
# 7    develop  impact     like
# 8     action    make     time
# 9     carbon    need     plan
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  1000  Alpha:  0.001  Eta:  0.001
#   Topic_0  Topic_1    Topic_2
# 0    year    china      trump
# 1   state     year         us
# 2   water   carbon     nation
# 3    like  develop      state
# 4     say    green    develop
# 5  report   nation  agreement
# 6    time    state       year
# 7    need     need     accord
# 8  impact  project         mr
# 9     use       us    support
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  1000  Alpha:  0.001  Eta:  0.1
#      Topic_0  Topic_1      Topic_2
# 0       year     year        trump
# 1     nation  develop           us
# 2      state    water    agreement
# 3       like    state        state
# 4      human   report       nation
# 5  scientist     need         year
# 6     impact   nation        china
# 7       time  project       accord
# 8       need      say       carbon
# 9       make     plan  environment
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  1000  Alpha:  0.001  Eta:  0.5
#      Topic_0 Topic_1      Topic_2
# 0      trump    year        state
# 1         us     say         year
# 2      state  carbon       nation
# 3  agreement    time      develop
# 4     nation    like       impact
# 5    develop      us        china
# 6       year  report      project
# 7     action     per  environment
# 8     accord     use       report
# 9       work    need         work
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  1000  Alpha:  0.1  Eta:  1e-05
#    Topic_0    Topic_1    Topic_2
# 0     year      trump      state
# 1  develop         us      trump
# 2   nation  agreement       year
# 3      per      state     report
# 4    china       year  scientist
# 5    water     nation       like
# 6     cent        say         us
# 7     need       make     carbon
# 8  nigeria    develop     nation
# 9  project     accord       rise
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  1000  Alpha:  0.1  Eta:  0.001
#      Topic_0    Topic_1  Topic_2
# 0      trump       year  develop
# 1         us      state     year
# 2  agreement     report    water
# 3      state     nation     need
# 4     nation  scientist   nation
# 5       year       like     make
# 6     action        say   carbon
# 7     accord     impact     work
# 8         mr      level    india
# 9      china      human     time
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  1000  Alpha:  0.1  Eta:  0.1
#    Topic_0      Topic_1    Topic_2
# 0     year        state      trump
# 1    water         year         us
# 2   report       nation  agreement
# 3      per         make      state
# 4  develop         time       year
# 5      say           us     nation
# 6   impact         like      power
# 7      use      develop         mr
# 8     like         need     carbon
# 9  project  environment     accord
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  1000  Alpha:  0.1  Eta:  0.5
#      Topic_0    Topic_1 Topic_2
# 0      trump    develop    year
# 1         us     nation   state
# 2      state      state    like
# 3  agreement    nigeria  report
# 4       year  agreement    time
# 5     nation      india  carbon
# 6      china       need   water
# 7     accord       year  nation
# 8       make       plan     say
# 9        say     action  impact
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  1000  Alpha:  0.5  Eta:  1e-05
#   Topic_0      Topic_1    Topic_2
# 0   state      develop      trump
# 1    year         year         us
# 2    like       nation       year
# 3     say        china  agreement
# 4  report         work     nation
# 5    need         plan      state
# 6    make         need      water
# 7  nation  environment      power
# 8  impact      project       time
# 9  carbon        state        say
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  1000  Alpha:  0.5  Eta:  0.001
#        Topic_0  Topic_1    Topic_2
# 0         year     year      trump
# 1        water     like         us
# 2          use   nation      state
# 3  environment   report  agreement
# 4        state    state     nation
# 5      develop      say    develop
# 6       nation       us       year
# 7        could  weather     action
# 8         need     time     carbon
# 9          per      per       need
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  1000  Alpha:  0.5  Eta:  0.1
#    Topic_0    Topic_1 Topic_2
# 0  develop      trump    year
# 1     year         us     per
# 2   nation      state   water
# 3    state       year  report
# 4  project  agreement    cent
# 5     work     nation    like
# 6     need        say    need
# 7     make     accord    risk
# 8   impact       time    time
# 9      use       like     say
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  1000  Alpha:  0.5  Eta:  0.5
#   Topic_0      Topic_1    Topic_2
# 0    year       nation      trump
# 1   state      develop         us
# 2   water        state       year
# 3      us        trump  agreement
# 4  report  environment     carbon
# 5  nation         work     nation
# 6   trump         year       like
# 7  impact        china      state
# 8     say         need    develop
# 9     per         make       time
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  2000  Alpha:  1e-05  Eta:  1e-05
#        Topic_0  Topic_1    Topic_2
# 0        state     year      trump
# 1       nation    water         us
# 2         year     warm  agreement
# 3      develop      per      state
# 4       report     like     nation
# 5  environment      use       year
# 6        human      say      china
# 7         work     time    develop
# 8    scientist  weather     accord
# 9         need     need     action
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  2000  Alpha:  1e-05  Eta:  0.001
#      Topic_0    Topic_1    Topic_2
# 0         us      state     nation
# 1      trump       year       year
# 2       year       warm    develop
# 3    develop     report    nigeria
# 4  agreement     nation     carbon
# 5       make       like         us
# 6      power      trump  agreement
# 7      state     impact      china
# 8       plan       time       need
# 9       need  scientist      water
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  2000  Alpha:  1e-05  Eta:  0.1
#      Topic_0    Topic_1  Topic_2
# 0      trump         us     year
# 1      state       year    water
# 2         us       warm   nation
# 3  agreement       like    state
# 4     nation      trump   report
# 5    develop       time     need
# 6     action      state  develop
# 7     accord  scientist    level
# 8     carbon       need  project
# 9         mr       make   impact
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  2000  Alpha:  1e-05  Eta:  0.5
#    Topic_0 Topic_1    Topic_2
# 0  develop   trump       year
# 1   invest      us      state
# 2     year    year    develop
# 3    water     say         us
# 4     need   state     nation
# 5    state  nation  agreement
# 6  project    like       warm
# 7   nation    time     carbon
# 8     food  report     impact
# 9     fund    warm      water
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  2000  Alpha:  0.001  Eta:  1e-05
#   Topic_0  Topic_1    Topic_2
# 0    year  develop      trump
# 1  carbon    china      state
# 2    need   nation         us
# 3   state     year     nation
# 4    warm  nigeria       year
# 5    like   invest  agreement
# 6    time    state     report
# 7     use     need      water
# 8    make     plan     accord
# 9     say       us        say
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  2000  Alpha:  0.001  Eta:  0.001
#    Topic_0    Topic_1    Topic_2
# 0    trump      state       year
# 1       us      trump      state
# 2     year       year     nation
# 3  develop  agreement      water
# 4     time     nation        per
# 5     like         us       warm
# 6     make     report   research
# 7     need     carbon    develop
# 8      say     accord     impact
# 9    china     action  scientist
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  2000  Alpha:  0.001  Eta:  0.1
#      Topic_0      Topic_1    Topic_2
# 0       year        state    develop
# 1      trump       nation         us
# 2      state         year       year
# 3         us           us     nation
# 4       like        trump        per
# 5      water       report  agreement
# 6       time  environment      trump
# 7     nation      develop     carbon
# 8  agreement         make      state
# 9        say         need       warm
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  2000  Alpha:  0.001  Eta:  0.5
#    Topic_0    Topic_1    Topic_2
# 0  develop      trump       year
# 1   nation         us      water
# 2    state      state      state
# 3   report       year       warm
# 4     year  agreement  scientist
# 5     risk     nation       like
# 6     fund       make     impact
# 7  project       need   research
# 8    trump    develop        say
# 9    green     action        use
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  2000  Alpha:  0.1  Eta:  1e-05
#      Topic_0    Topic_1  Topic_2
# 0       year      trump  develop
# 1      state         us    water
# 2       warm      state     year
# 3     report  agreement    state
# 4         us     nation     need
# 5     nation       year   impact
# 6       time      china  project
# 7      water        say   nation
# 8  scientist    develop      use
# 9       like       make     area
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  2000  Alpha:  0.1  Eta:  0.001
#      Topic_0    Topic_1    Topic_2
# 0      state       year      trump
# 1       year       time         us
# 2    develop       warm      state
# 3     report       like  agreement
# 4     nation        say     accord
# 5       need     nation       year
# 6         us       make     nation
# 7       plan  scientist       warm
# 8  agreement         us      water
# 9     carbon      human    develop
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  2000  Alpha:  0.1  Eta:  0.1
#      Topic_0  Topic_1  Topic_2
# 0      trump       us     year
# 1      state     year     need
# 2       year    china    water
# 3     nation  develop      use
# 4         us    trump  develop
# 5       warm   nation     make
# 6     report   invest   impact
# 7  agreement    state     food
# 8       like   carbon      say
# 9       time    power      per
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  2000  Alpha:  0.1  Eta:  0.5
#     Topic_0    Topic_1  Topic_2
# 0      year      trump     year
# 1    nation      state    water
# 2    report         us     need
# 3      warm  agreement    state
# 4     state    develop     time
# 5        us     nation     like
# 6    carbon       year       us
# 7     trump      china  develop
# 8    impact     accord     work
# 9  research    support      per
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  2000  Alpha:  0.5  Eta:  1e-05
#        Topic_0 Topic_1  Topic_2
# 0      develop   trump  develop
# 1         year      us     year
# 2       invest    year   nation
# 3       nation   state    water
# 4        state    warm     need
# 5  environment    like     plan
# 6        green  nation     work
# 7        china  report      per
# 8        india     say    state
# 9         need    time      say
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  2000  Alpha:  0.5  Eta:  0.001
#    Topic_0    Topic_1   Topic_2
# 0     year      trump     state
# 1  develop         us     water
# 2     need       year      year
# 3   nation      state   develop
# 4    china  agreement     trump
# 5    green     nation    nation
# 6  nigeria       time  research
# 7  project     report      warm
# 8     work        say     level
# 9   invest       like       use
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  2000  Alpha:  0.5  Eta:  0.1
#      Topic_0  Topic_1 Topic_2
# 0      trump     year    year
# 1    develop    water   trump
# 2         us    state      us
# 3     nation   nation   state
# 4  agreement     like  carbon
# 5      state   report    warm
# 6       year   impact  report
# 7      china     rise    time
# 8     accord    level     per
# 9    support  weather     say
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  2000  Alpha:  0.5  Eta:  0.5
#    Topic_0    Topic_1    Topic_2
# 0   nation      water      trump
# 1     year       year         us
# 2    state     carbon       year
# 3  develop        per      state
# 4     need       warm        say
# 5   report  scientist  agreement
# 6     plan     nation       warm
# 7   impact    develop       time
# 8  project      state       make
# 9   action       time     accord
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  3000  Alpha:  1e-05  Eta:  1e-05
#      Topic_0  Topic_1    Topic_2
# 0      trump  develop       year
# 1         us     year      state
# 2      state   invest       warm
# 3  agreement    power     report
# 4     nation   nation       like
# 5       year     need     nation
# 6    develop    china        say
# 7     action       us  scientist
# 8     accord    state       time
# 9     commit     fund      water
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  3000  Alpha:  1e-05  Eta:  0.001
#   Topic_0  Topic_1      Topic_2
# 0    year    state        trump
# 1     per  develop        state
# 2      us   nation         year
# 3    cent     year           us
# 4  nation    trump       nation
# 5    need    water  environment
# 6  carbon   report         warm
# 7  report     plan    agreement
# 8    like       us         like
# 9    time   region       accord
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  3000  Alpha:  1e-05  Eta:  0.1
#      Topic_0  Topic_1 Topic_2
# 0    develop     year   trump
# 1      state      per      us
# 2     nation    water    year
# 3      china     need   state
# 4       year   carbon    warm
# 5         us     cent     say
# 6  agreement      use  nation
# 7       work   invest  report
# 8    nigeria  project    like
# 9    sustain  develop    time
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  3000  Alpha:  1e-05  Eta:  0.5
#      Topic_0  Topic_1  Topic_2
# 0      trump     year    state
# 1         us  develop  develop
# 2       year    china     year
# 3      state     need    water
# 4     nation   nation      per
# 5  agreement     food   nation
# 6        say   impact  project
# 7       time       us     plan
# 8       warm   region  nigeria
# 9       make    water     cent
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  3000  Alpha:  0.001  Eta:  1e-05
#      Topic_0  Topic_1    Topic_2
# 0      trump     year       year
# 1         us  develop       warm
# 2      state      per       like
# 3  agreement    state  scientist
# 4     nation    water        say
# 5       year   nation     nation
# 6     accord     need      human
# 7    develop   report       time
# 8         mr     plan      state
# 9      power     cent       make
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  3000  Alpha:  0.001  Eta:  0.001
#      Topic_0    Topic_1    Topic_2
# 0     nation      trump       year
# 1      china         us      state
# 2       year      state       warm
# 3      state       year       like
# 4    develop     nation        say
# 5  agreement    develop  scientist
# 6     invest  agreement       time
# 7         us     report      water
# 8      power     action     report
# 9       plan       make   research
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  3000  Alpha:  0.001  Eta:  0.1
#    Topic_0    Topic_1    Topic_2
# 0     year         us      trump
# 1  develop      trump       year
# 2    state      state         us
# 3    water  agreement      state
# 4   nation     nation        say
# 5     need     action     nation
# 6   impact     carbon       time
# 7      use       year       warm
# 8   report    develop  scientist
# 9  project       like    develop
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  3000  Alpha:  0.001  Eta:  0.5
#      Topic_0   Topic_1  Topic_2
# 0      state      year    trump
# 1      trump     water       us
# 2       year      warm   nation
# 3        per      time    state
# 4     nation  research  develop
# 5         us      need     year
# 6     report      like     like
# 7  agreement       say    china
# 8    develop     state     work
# 9     accord   weather     make
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  3000  Alpha:  0.1  Eta:  1e-05
#   Topic_0 Topic_1    Topic_2
# 0    year    year      state
# 1   trump    like    develop
# 2  report    time     nation
# 3      us    warm         us
# 4     per   trump       year
# 5      mr   state      trump
# 6  accord     say  agreement
# 7   water    make     carbon
# 8  farmer    need     action
# 9  nation      us     impact
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  3000  Alpha:  0.1  Eta:  0.001
#      Topic_0  Topic_1  Topic_2
# 0      trump  develop     year
# 1         us     year    china
# 2      state    water     time
# 3       year   nation   nation
# 4  agreement  project     work
# 5     nation      per  student
# 6       warm     need  develop
# 7     report   impact     make
# 8        say      use     need
# 9     accord    state     last
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  3000  Alpha:  0.1  Eta:  0.1
#      Topic_0  Topic_1    Topic_2
# 0       year    state      trump
# 1       warm   nation         us
# 2       like     year  agreement
# 3       time       us      state
# 4  scientist  develop    develop
# 5      state      say     nation
# 6      water   report       year
# 7     report    water       need
# 8        say    trump     commit
# 9        use    china         mr
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  3000  Alpha:  0.1  Eta:  0.5
#      Topic_0    Topic_1 Topic_2
# 0       year      state    year
# 1     nation      trump  carbon
# 2        say         us    warm
# 3      trump       year   power
# 4    develop    develop  report
# 5      china     nation      us
# 6       warm      water    time
# 7       like  agreement  nation
# 8   research       need     per
# 9  scientist       plan     say
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  3000  Alpha:  0.5  Eta:  1e-05
#      Topic_0      Topic_1    Topic_2
# 0      trump        state       year
# 1         us       report       like
# 2  agreement      develop       warm
# 3     nation       nation       time
# 4      state        water        say
# 5    develop  environment      state
# 6      china         plan       make
# 7       year        trump         us
# 8     accord         year  scientist
# 9         mr         need      human
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  3000  Alpha:  0.5  Eta:  0.001
#      Topic_0 Topic_1    Topic_2
# 0      trump    year         us
# 1       year   state    develop
# 2       warm     per      trump
# 3         us   water     nation
# 4       time    need      state
# 5       like  nation  agreement
# 6     report  carbon      china
# 7      state  report       year
# 8  scientist     say       work
# 9   research   could     accord
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  3000  Alpha:  0.5  Eta:  0.1
#    Topic_0    Topic_1    Topic_2
# 0    state       year      trump
# 1    water      state         us
# 2     year     nation       year
# 3  develop       warm  agreement
# 4      say    develop     nation
# 5     need     report     carbon
# 6     like    weather      state
# 7     time  scientist     accord
# 8    trump       time      power
# 9       us       like       need
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  3000  Alpha:  0.5  Eta:  0.5
#    Topic_0    Topic_1    Topic_2
# 0  develop       year      trump
# 1     year      water         us
# 2     need       warm      state
# 3    state       time  agreement
# 4   nation     report     nation
# 5     plan       like     accord
# 6  sustain        use      china
# 7     fund  scientist       year
# 8  project     nation       make
# 9     work        say        say

# %% [markdown]
# ## HERE

# %%
num_topics = [5, 6, 7]
max_dfs = [0.5]
max_features = [1000, 3000]
norm_type = [ '_stem']

alphas = [0.001, 0.1, 0.5]
etas = [0.001, 0.1, 0.5]

stop_words = lucem_illud.stop_words_basic +  ['climat', 'chang', 'like', 'year','mr', 'say','could']

# %%
topic_loop(news_df, stop_words, num_topics, max_dfs, max_features, norm_type, alphas, etas, random_number=1024)
# Out:
# /home/sunjoo/.local/lib/python3.6/site-packages/gensim/models/ldamodel.py:802: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  1000  Alpha:  0.001  Eta:  0.001
#      Topic_0    Topic_1   Topic_2  Topic_3  Topic_4
# 0      trump       time   nigeria  develop  develop
# 1      state       rise     water    china      per
# 2         us  scientist      food       us     cent
# 3  agreement      human    nation     work   nation
# 4     nation    weather   develop    trump     risk
# 5     report       make       use     need    china
# 6     accord      level  research   nation   sector
# 7     carbon      flood     state     make    water
# 8     action      state      need     meet    state
# 9       plan         us    africa    power     plan
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  1000  Alpha:  0.001  Eta:  0.1
#      Topic_0    Topic_1   Topic_2  Topic_3  Topic_4
# 0      trump       time   nigeria  develop  develop
# 1      state       rise     water    china      per
# 2         us  scientist      food       us     cent
# 3  agreement      human    nation     work   nation
# 4     nation    weather   develop    trump     risk
# 5     report       make       use     need    china
# 6     accord      level  research   nation   sector
# 7     carbon      flood     state     make    water
# 8     action      state      need     meet    state
# 9       plan         us    africa    power     plan
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  1000  Alpha:  0.001  Eta:  0.5
#      Topic_0    Topic_1   Topic_2  Topic_3  Topic_4
# 0      trump       time   nigeria  develop  develop
# 1      state       rise     water    china      per
# 2         us  scientist      food       us     cent
# 3  agreement      human    nation     work   nation
# 4     nation    weather   develop    trump     risk
# 5     report       make       use     need    china
# 6     accord      level  research   nation   sector
# 7     carbon      flood     state     make    water
# 8     action      state      need     meet    state
# 9       plan         us    africa    power     plan
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  1000  Alpha:  0.1  Eta:  0.001
#      Topic_0    Topic_1   Topic_2  Topic_3  Topic_4
# 0      trump       time   nigeria  develop  develop
# 1      state       rise     water    china      per
# 2         us  scientist      food       us     cent
# 3  agreement      human    nation     work   nation
# 4     nation    weather   develop    trump     risk
# 5     report       make       use     need    china
# 6     accord      level  research   nation   sector
# 7     carbon      flood     state     make    water
# 8     action      state      need     meet    state
# 9       plan         us    africa    power     plan
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  1000  Alpha:  0.1  Eta:  0.1
#      Topic_0    Topic_1   Topic_2  Topic_3  Topic_4
# 0      trump       time   nigeria  develop  develop
# 1      state       rise     water    china      per
# 2         us  scientist      food       us     cent
# 3  agreement      human    nation     work   nation
# 4     nation    weather   develop    trump     risk
# 5     report       make       use     need    china
# 6     accord      level  research   nation   sector
# 7     carbon      flood     state     make    water
# 8     action      state      need     meet    state
# 9       plan         us    africa    power     plan
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  1000  Alpha:  0.1  Eta:  0.5
#      Topic_0    Topic_1   Topic_2  Topic_3  Topic_4
# 0      trump       time   nigeria  develop  develop
# 1      state       rise     water    china      per
# 2         us  scientist      food       us     cent
# 3  agreement      human    nation     work   nation
# 4     nation    weather   develop    trump     risk
# 5     report       make       use     need    china
# 6     accord      level  research   nation   sector
# 7     carbon      flood     state     make    water
# 8     action      state      need     meet    state
# 9       plan         us    africa    power     plan
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  1000  Alpha:  0.5  Eta:  0.001
#      Topic_0    Topic_1   Topic_2  Topic_3  Topic_4
# 0      trump       time   nigeria  develop  develop
# 1      state       rise     water       us      per
# 2         us  scientist      food    china     cent
# 3  agreement      human    nation     work   nation
# 4     nation       make   develop    trump    state
# 5     report    weather       use     need    china
# 6     accord      level  research   nation     risk
# 7     carbon      flood     state     meet    water
# 8     action      state      time     make   sector
# 9       plan         us      need    power     area
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  1000  Alpha:  0.5  Eta:  0.1
#      Topic_0    Topic_1   Topic_2  Topic_3  Topic_4
# 0      trump       time   nigeria  develop  develop
# 1      state       rise     water       us      per
# 2         us  scientist      food    china     cent
# 3  agreement      human    nation     work   nation
# 4     nation       make   develop    trump    state
# 5     report    weather       use     need    china
# 6     accord      level  research   nation     risk
# 7     carbon      flood     state     meet    water
# 8     action      state      time     make   sector
# 9       plan         us      need    power     area
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  1000  Alpha:  0.5  Eta:  0.5
#      Topic_0    Topic_1   Topic_2  Topic_3  Topic_4
# 0      trump       time   nigeria  develop  develop
# 1      state       rise     water       us      per
# 2         us      human      food    china     cent
# 3  agreement  scientist    nation     work   nation
# 4     nation    weather   develop    trump    china
# 5     report       make       use     need    state
# 6     accord      level  research   nation     risk
# 7     carbon      flood     state     meet    water
# 8     action      state      time     make   sector
# 9       plan         us      need    power     area
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  3000  Alpha:  0.001  Eta:  0.001
#    Topic_0    Topic_1  Topic_2  Topic_3  Topic_4
# 0   nation      trump       us     time    water
# 1  develop         us    india    state  develop
# 2  nigeria      state  develop   nation  project
# 3    state  agreement   nation    trump    state
# 4    china     carbon    power     warm     plan
# 5     food       warm     work       us      use
# 6     need     accord     time    human  sustain
# 7      per        gas    state   report   nation
# 8      use       risk    china     make     area
# 9  sustain     invest   action  weather   farmer
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  3000  Alpha:  0.001  Eta:  0.1
#    Topic_0    Topic_1  Topic_2  Topic_3  Topic_4
# 0   nation      trump       us     time    water
# 1  develop         us    india    state  develop
# 2  nigeria      state  develop   nation  project
# 3    state  agreement   nation    trump    state
# 4    china     carbon    power     warm     plan
# 5     need       warm     time       us      use
# 6     food     accord     work    human  sustain
# 7      per        gas    state   report   nation
# 8      use       risk    china     make     area
# 9  sustain     invest   action  weather   farmer
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  3000  Alpha:  0.001  Eta:  0.5
#    Topic_0    Topic_1  Topic_2  Topic_3  Topic_4
# 0   nation      trump       us     time    water
# 1  develop         us    india    state  develop
# 2  nigeria      state  develop   nation  project
# 3    state  agreement   nation    trump    state
# 4    china     carbon    power     warm     plan
# 5     food       warm     time       us  sustain
# 6     need     accord     work    human      use
# 7      per        gas    state   report   nation
# 8      use       risk    china     make     area
# 9  sustain     invest   action  weather   farmer
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  3000  Alpha:  0.1  Eta:  0.001
#    Topic_0    Topic_1  Topic_2  Topic_3  Topic_4
# 0   nation      trump       us     time    water
# 1  develop         us    india    state  develop
# 2  nigeria      state  develop   nation  project
# 3    state  agreement   nation    trump    state
# 4    china     carbon    power     warm     plan
# 5     food       warm     work       us      use
# 6     need     accord     time    human  sustain
# 7      per        gas    state   report   nation
# 8      use       risk    china     make     area
# 9  sustain     invest   action  weather   farmer
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  3000  Alpha:  0.1  Eta:  0.1
#    Topic_0    Topic_1  Topic_2  Topic_3  Topic_4
# 0   nation      trump       us     time    water
# 1  develop         us    india    state  develop
# 2  nigeria      state  develop   nation  project
# 3    state  agreement   nation    trump    state
# 4    china     carbon    power     warm     plan
# 5     food       warm     work       us      use
# 6     need     accord     time    human  sustain
# 7      per        gas    state   report   nation
# 8      use       risk    china     make     area
# 9  sustain     invest   action  weather   farmer
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  3000  Alpha:  0.1  Eta:  0.5
#    Topic_0    Topic_1  Topic_2  Topic_3  Topic_4
# 0   nation      trump       us     time    water
# 1  develop         us    india    state  develop
# 2  nigeria      state  develop   nation  project
# 3    state  agreement   nation    trump    state
# 4    china     carbon    power     warm     plan
# 5     food       warm     time       us  sustain
# 6     need     accord     work    human      use
# 7      per        gas    state   report   nation
# 8      use       risk    china     make     area
# 9  sustain     invest   action  weather   farmer
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  3000  Alpha:  0.5  Eta:  0.001
#    Topic_0    Topic_1  Topic_2  Topic_3  Topic_4
# 0   nation      trump       us    state    water
# 1  develop         us    india   nation  develop
# 2  nigeria      state  develop     time  project
# 3    state  agreement   nation    trump     plan
# 4    china     carbon    power     warm    state
# 5     need       warm     time       us      use
# 6     food     accord     work   report  sustain
# 7      per        gas    state    human   nation
# 8      use       risk   action     make     area
# 9  sustain       make    china  weather     need
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  3000  Alpha:  0.5  Eta:  0.1
#    Topic_0    Topic_1  Topic_2  Topic_3  Topic_4
# 0   nation      trump       us    state    water
# 1  develop         us    india   nation  develop
# 2  nigeria      state  develop     time  project
# 3    state  agreement   nation    trump     plan
# 4    china     carbon    power     warm    state
# 5     need       warm     time       us      use
# 6     food     accord     work    human  sustain
# 7      per        gas    state   report   nation
# 8      use       risk   action     make     area
# 9  sustain       make    china  weather     need
#
# Norm:  _stem Num topics:  5 , Max df:  0.5  Max features:  3000  Alpha:  0.5  Eta:  0.5
#    Topic_0    Topic_1  Topic_2  Topic_3  Topic_4
# 0   nation      trump       us    state    water
# 1  develop         us    india   nation  develop
# 2  nigeria      state  develop     time  project
# 3    state  agreement   nation    trump    state
# 4    china     carbon    power     warm     plan
# 5     food       warm     time       us      use
# 6     need     accord     work    human  sustain
# 7      per        gas    state   report   nation
# 8      use       risk   action     make     area
# 9  sustain       make    china  weather     need
#
# Norm:  _stem Num topics:  6 , Max df:  0.5  Max features:  1000  Alpha:  0.001  Eta:  0.001
#        Topic_0    Topic_1    Topic_2      Topic_3  Topic_4    Topic_5
# 0        state       time      water      develop      per      trump
# 1       report       rise        use         work  develop         us
# 2       carbon    weather   research         need     cent  agreement
# 3       nation      level  scientist          uae    water      china
# 4         plan      flood    nigeria         make   nation     nation
# 5        trump  scientist       food       nation   region      state
# 6  environment       make     nation        green     area     accord
# 7       action      human       time        china   sector     leader
# 8       impact      storm    develop           us     risk    develop
# 9        water      state       need  environment  million       meet
#
# Norm:  _stem Num topics:  6 , Max df:  0.5  Max features:  1000  Alpha:  0.001  Eta:  0.1
#        Topic_0    Topic_1    Topic_2      Topic_3  Topic_4    Topic_5
# 0        state       time      water      develop      per      trump
# 1       report       rise        use         work  develop         us
# 2       carbon    weather   research         need     cent  agreement
# 3       nation      level  scientist          uae    water      china
# 4         plan      flood       food         make   nation     nation
# 5        trump  scientist    nigeria       nation   region      state
# 6  environment       make     nation        green     area     accord
# 7       action      human       time        china   sector     leader
# 8       impact      storm    develop           us     risk    develop
# 9        water      state       need  environment  million       meet
#
# Norm:  _stem Num topics:  6 , Max df:  0.5  Max features:  1000  Alpha:  0.001  Eta:  0.5
#        Topic_0    Topic_1    Topic_2  Topic_3  Topic_4    Topic_5
# 0        state       time      water  develop      per      trump
# 1       report       rise        use     work  develop         us
# 2       carbon    weather   research     need     cent  agreement
# 3       nation      level  scientist      uae    water      china
# 4         plan      flood       food     make   nation     nation
# 5        trump       make    nigeria   nation   region      state
# 6       action  scientist       time    green     area     accord
# 7  environment      human     nation    china   sector     leader
# 8       impact      storm    develop       us     risk    develop
# 9         need      state       need    power  million       meet
#
# Norm:  _stem Num topics:  6 , Max df:  0.5  Max features:  1000  Alpha:  0.1  Eta:  0.001
#        Topic_0    Topic_1    Topic_2  Topic_3  Topic_4    Topic_5
# 0        state       time      water  develop      per      trump
# 1       report       rise        use     work  develop         us
# 2       carbon    weather   research     need     cent  agreement
# 3         plan      level  scientist      uae    water      china
# 4       nation      flood       food     make   nation     nation
# 5        trump       make    nigeria   nation     area      state
# 6  environment  scientist     nation    china     risk     accord
# 7       action      human       time    green   sector     leader
# 8       impact      storm    develop       us   region    develop
# 9        water      state      state     help    state       meet
#
# Norm:  _stem Num topics:  6 , Max df:  0.5  Max features:  1000  Alpha:  0.1  Eta:  0.1
#        Topic_0    Topic_1    Topic_2  Topic_3  Topic_4    Topic_5
# 0        state       time      water  develop      per      trump
# 1       report       rise        use     work  develop         us
# 2       carbon    weather   research     need     cent  agreement
# 3         plan      level  scientist      uae    water      china
# 4       nation      flood       food     make   nation     nation
# 5        trump       make    nigeria   nation     area      state
# 6  environment  scientist     nation    china     risk     accord
# 7       action      human       time    green   sector     leader
# 8       impact      storm    develop       us   region    develop
# 9        water      state      state     help    state       meet
#
# Norm:  _stem Num topics:  6 , Max df:  0.5  Max features:  1000  Alpha:  0.1  Eta:  0.5
#        Topic_0    Topic_1    Topic_2  Topic_3  Topic_4    Topic_5
# 0        state       time      water  develop      per      trump
# 1       report       rise        use     work  develop         us
# 2       carbon    weather   research     need     cent  agreement
# 3       nation      level  scientist      uae    water      china
# 4         plan      flood       food     make   nation     nation
# 5        trump       make    nigeria   nation     area      state
# 6  environment      human       time    china     risk     accord
# 7       action  scientist     nation    green   region     leader
# 8       impact      storm    develop       us   sector    develop
# 9        water      state       need    power  million       meet
#
# Norm:  _stem Num topics:  6 , Max df:  0.5  Max features:  1000  Alpha:  0.5  Eta:  0.001
#        Topic_0    Topic_1    Topic_2  Topic_3  Topic_4    Topic_5
# 0        state       rise      water  develop      per      trump
# 1       report       time       food     work  develop         us
# 2       carbon    weather        use     need     cent  agreement
# 3       nation      level   research      uae   nation     nation
# 4         plan      flood  scientist     make    water      china
# 5        trump      human     nation   nation     risk      state
# 6        water  scientist    nigeria    china    state     accord
# 7  environment       make       time       us     area     leader
# 8       impact      storm    develop    power  million    develop
# 9       action      state      state     help   region       meet
# Norm:  _stem Num topics:  6 , Max df:  0.5  Max features:  1000  Alpha:  0.5  Eta:  0.1
#        Topic_0    Topic_1    Topic_2  Topic_3  Topic_4    Topic_5
# 0        state       rise      water  develop      per      trump
# 1       report       time       food     work  develop         us
# 2       carbon    weather        use     need     cent  agreement
# 3       nation      level   research      uae   nation     nation
# 4         plan      flood  scientist     make    water      china
# 5        trump      human     nation   nation     risk      state
# 6        water  scientist       time    china    state     accord
# 7  environment       make    nigeria       us     area     leader
# 8       impact      storm    develop    power  million    develop
# 9       action      state      state     help   region       meet
#
# Norm:  _stem Num topics:  6 , Max df:  0.5  Max features:  1000  Alpha:  0.5  Eta:  0.5
#        Topic_0    Topic_1    Topic_2  Topic_3  Topic_4    Topic_5
# 0        state       rise      water  develop      per      trump
# 1       report       time       food     work  develop         us
# 2       carbon    weather        use     need     cent  agreement
# 3       nation      level   research      uae   nation     nation
# 4         plan      flood  scientist     make    water      china
# 5        trump      human     nation   nation     risk      state
# 6        water       make       time    china     area     accord
# 7  environment  scientist    develop       us    state     leader
# 8       impact      storm    nigeria    power  million    develop
# 9       action      state      state     help   region       meet
#
# Norm:  _stem Num topics:  6 , Max df:  0.5  Max features:  3000  Alpha:  0.001  Eta:  0.001
#    Topic_0    Topic_1  Topic_2    Topic_3    Topic_4      Topic_5
# 0   nation      trump    india      trump    develop        water
# 1  nigeria         us       us     nation      water        state
# 2  develop      state  develop       time    project       impact
# 3    china  agreement   nation      state       plan      weather
# 4     need     carbon    power       warm     nation     research
# 5    state     accord     time         us    sustain         food
# 6      per       warm    china      human        use       farmer
# 7   africa        gas    state     report      state         make
# 8      use     invest      uae       make       area  environment
# 9     food       risk     work  scientist  agreement       forest
#
# Norm:  _stem Num topics:  6 , Max df:  0.5  Max features:  3000  Alpha:  0.001  Eta:  0.1
#    Topic_0    Topic_1  Topic_2    Topic_3    Topic_4      Topic_5
# 0   nation      trump    india      trump    develop        water
# 1  nigeria         us       us     nation      water        state
# 2  develop      state  develop       time    project       impact
# 3    china  agreement   nation      state       plan      weather
# 4     need     carbon    power       warm     nation     research
# 5    state     accord     time         us    sustain         food
# 6      per       warm    china      human        use       farmer
# 7   africa        gas    state     report      state         make
# 8      use     invest      uae       make       area  environment
# 9     food       risk     work  scientist  agreement       forest
#
# Norm:  _stem Num topics:  6 , Max df:  0.5  Max features:  3000  Alpha:  0.001  Eta:  0.5
#    Topic_0    Topic_1  Topic_2    Topic_3    Topic_4      Topic_5
# 0   nation      trump    india      trump    develop        water
# 1  nigeria         us       us     nation      water        state
# 2  develop      state  develop       time    project       impact
# 3    china  agreement    power      state     nation      weather
# 4     need     carbon   nation       warm    sustain     research
# 5    state     accord     time         us       plan         food
# 6      per       warm    china      human        use       farmer
# 7   africa        gas    state     report      state         make
# 8     food     invest   action       make       area  environment
# 9      use       risk     work  scientist  agreement       forest
#
# Norm:  _stem Num topics:  6 , Max df:  0.5  Max features:  3000  Alpha:  0.1  Eta:  0.001
#    Topic_0    Topic_1  Topic_2    Topic_3    Topic_4      Topic_5
# 0   nation      trump    india      trump    develop        water
# 1  nigeria         us       us     nation      water        state
# 2  develop      state  develop       time    project       impact
# 3    china  agreement   nation      state       plan      weather
# 4     need     carbon    power       warm     nation     research
# 5    state     accord     time         us    sustain         food
# 6      per       warm    china      human        use       farmer
# 7     food        gas    state     report       area         make
# 8   africa     invest     work       make      state  environment
# 9      use       risk      uae  scientist  agreement       forest
#
# Norm:  _stem Num topics:  6 , Max df:  0.5  Max features:  3000  Alpha:  0.1  Eta:  0.1
#    Topic_0    Topic_1  Topic_2    Topic_3    Topic_4      Topic_5
# 0   nation      trump    india      trump    develop        water
# 1  nigeria         us       us     nation      water        state
# 2  develop      state  develop       time    project       impact
# 3    china  agreement    power      state       plan      weather
# 4     need     carbon   nation       warm     nation     research
# 5    state     accord     time         us    sustain         food
# 6      per       warm    china      human        use       farmer
# 7     food        gas    state     report      state         make
# 8      use     invest     work       make       area  environment
# 9   africa       risk      uae  scientist  agreement       forest
#
# Norm:  _stem Num topics:  6 , Max df:  0.5  Max features:  3000  Alpha:  0.1  Eta:  0.5
#    Topic_0    Topic_1  Topic_2    Topic_3    Topic_4      Topic_5
# 0   nation      trump    india      trump    develop        water
# 1  nigeria         us       us     nation      water        state
# 2  develop      state  develop       time    project       impact
# 3    china  agreement    power      state     nation      weather
# 4     need     carbon   nation       warm       plan     research
# 5    state     accord     time         us    sustain         food
# 6      per       warm    china      human        use       farmer
# 7     food        gas    state     report      state         make
# 8   africa     invest   action       make       area  environment
# 9      use       risk     work  scientist  agreement       forest
#
# Norm:  _stem Num topics:  6 , Max df:  0.5  Max features:  3000  Alpha:  0.5  Eta:  0.001
#    Topic_0    Topic_1  Topic_2    Topic_3    Topic_4      Topic_5
# 0   nation      trump       us      trump    develop        water
# 1  nigeria         us    india     nation      water        state
# 2  develop      state  develop       time    project       impact
# 3    china  agreement    power      state       plan         make
# 4     need     carbon   nation       warm     nation     research
# 5    state       warm     time         us    sustain  environment
# 6      per        gas     work     report        use      weather
# 7     food     accord    state      human       area       forest
# 8      use     invest    china       make      state         work
# 9  sustain       risk   action  scientist  agreement         food
#
# Norm:  _stem Num topics:  6 , Max df:  0.5  Max features:  3000  Alpha:  0.5  Eta:  0.1
#    Topic_0    Topic_1  Topic_2    Topic_3    Topic_4      Topic_5
# 0   nation      trump       us      trump    develop        water
# 1  nigeria         us    india     nation      water        state
# 2  develop      state  develop       time    project       impact
# 3    china  agreement    power      state       plan         make
# 4     need     carbon   nation       warm     nation     research
# 5    state       warm     time         us    sustain      weather
# 6      per        gas     work     report        use  environment
# 7     food     accord    china      human       area       forest
# 8      use     invest    state       make      state         work
# 9  sustain       risk   action  scientist  agreement         food
#
# Norm:  _stem Num topics:  6 , Max df:  0.5  Max features:  3000  Alpha:  0.5  Eta:  0.5
#    Topic_0    Topic_1  Topic_2 Topic_3    Topic_4      Topic_5
# 0   nation      trump       us   trump    develop        water
# 1  nigeria         us    india  nation      water        state
# 2  develop      state  develop    time    project       impact
# 3    china  agreement    power   state     nation         make
# 4     need     carbon   nation    warm       plan  environment
# 5    state       warm     time      us    sustain     research
# 6      per     accord     work  report        use      weather
# 7     food        gas    state   human       area       forest
# 8      use     invest    china    make      state         work
# 9  sustain       risk   action    need  agreement         food
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  1000  Alpha:  0.001  Eta:  0.001
#        Topic_0    Topic_1    Topic_2      Topic_3  Topic_4    Topic_5  Topic_6
# 0        state       rise      water      develop      per      trump  develop
# 1       report       time       food         work  develop         us  project
# 2       carbon    weather    nigeria         need     cent  agreement     time
# 3       nation  scientist        use          uae    water      china   nation
# 4         plan      level  scientist        china   nation     nation   africa
# 5  environment      flood   research         risk     risk      state  support
# 6       impact      human     nation         make     area     accord    first
# 7        trump       make     school           us    state     leader     fund
# 8       action      storm      state       nation  million    develop     need
# 9        water      state       time  environment   region       meet     work
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  1000  Alpha:  0.001  Eta:  0.1
#        Topic_0    Topic_1    Topic_2      Topic_3  Topic_4    Topic_5  Topic_6
# 0        state       rise      water      develop      per      trump  develop
# 1       report       time       food         work  develop         us  project
# 2       carbon    weather        use         need     cent  agreement   nation
# 3       nation  scientist    nigeria          uae    water      china     time
# 4         plan      level  scientist        china   nation     nation   africa
# 5  environment      flood   research         risk     risk      state  support
# 6       impact      human     nation         make     area     accord     fund
# 7       action       make     school           us    state     leader    first
# 8        trump      storm      state       nation  million    develop     need
# 9        water      state       time  environment   region       meet     work
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  1000  Alpha:  0.001  Eta:  0.5
#        Topic_0    Topic_1    Topic_2      Topic_3  Topic_4    Topic_5  Topic_6
# 0        state       rise      water      develop      per      trump  develop
# 1       report       time       food         work     cent         us  project
# 2       nation    weather        use         need  develop  agreement   nation
# 3       carbon  scientist  scientist          uae    water      china     time
# 4         plan      level   research        china   nation     nation   africa
# 5  environment      flood    nigeria         risk     risk      state  support
# 6        trump      human     school         make     area     accord     fund
# 7       impact       make     nation           us  million     leader    first
# 8       action      storm       time       nation   region    develop     need
# 9        water      state      state  environment    state       meet     work
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  1000  Alpha:  0.1  Eta:  0.001
#        Topic_0    Topic_1    Topic_2      Topic_3  Topic_4    Topic_5  Topic_6
# 0        state       rise      water      develop      per      trump  develop
# 1       report       time       food         work  develop         us  project
# 2       carbon    weather        use         need     cent  agreement   nation
# 3       nation  scientist  scientist          uae    water      china     time
# 4         plan      level    nigeria        china   nation     nation   africa
# 5  environment      flood   research         risk     risk      state     fund
# 6        water      human     nation         make     area     accord  support
# 7       impact       make     school           us    state     leader    first
# 8        trump      storm      state       nation  million    develop     need
# 9       action      state       time  environment   region       meet     work
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  1000  Alpha:  0.1  Eta:  0.1
#        Topic_0    Topic_1    Topic_2      Topic_3  Topic_4    Topic_5  Topic_6
# 0        state       rise      water      develop      per      trump  develop
# 1       report       time       food         work  develop         us  project
# 2       carbon    weather        use         need     cent  agreement   nation
# 3       nation  scientist  scientist          uae    water      china     time
# 4         plan      level   research        china   nation     nation   africa
# 5  environment      flood    nigeria         risk     risk      state     fund
# 6        water      human     school         make     area     accord  support
# 7       impact       make     nation           us    state     leader    first
# 8        trump      storm      state       nation  million    develop     need
# 9       action      state       time  environment   region       meet     work
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  1000  Alpha:  0.1  Eta:  0.5
#        Topic_0    Topic_1    Topic_2      Topic_3  Topic_4    Topic_5  Topic_6
# 0        state       rise      water      develop      per      trump  develop
# 1       report       time       food         work     cent         us  project
# 2       carbon    weather        use         need  develop  agreement   nation
# 3       nation      level  scientist          uae    water      china     time
# 4         plan  scientist   research        china   nation     nation   africa
# 5        trump      flood     school         risk     risk      state     fund
# 6  environment      human     nation         make     area     accord  support
# 7       impact       make       time           us  million     leader    first
# 8       action      storm    nigeria       nation    state    develop     need
# 9        water      state      state  environment   region       meet     work
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  1000  Alpha:  0.5  Eta:  0.001
#        Topic_0    Topic_1    Topic_2  Topic_3  Topic_4    Topic_5  Topic_6
# 0        state       rise      water  develop      per      trump  develop
# 1       report    weather       food     work     cent         us   nation
# 2       carbon      level        use     need  develop  agreement  project
# 3         plan      flood  scientist      uae    water     nation     time
# 4       nation       time   research    china   nation      china     fund
# 5        water  scientist     school     risk    state      state     need
# 6        trump       make     nation     make     risk     accord  support
# 7       impact      human      state       us     area     leader   africa
# 8  environment      storm       time   nation  million    develop    first
# 9       action      state    develop    power   sector       meet     take
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  1000  Alpha:  0.5  Eta:  0.1
#        Topic_0    Topic_1    Topic_2  Topic_3  Topic_4    Topic_5  Topic_6
# 0        state       rise      water  develop      per      trump  develop
# 1       report    weather       food     work     cent         us   nation
# 2       carbon      level        use     need  develop  agreement  project
# 3         plan      flood  scientist      uae    water     nation     time
# 4       nation       time   research    china   nation      china     fund
# 5        water  scientist     school     risk    state      state     need
# 6        trump       make     nation     make     risk     accord  support
# 7       impact      human      state       us     area     leader   africa
# 8  environment      storm       time   nation  million    develop    first
# 9       action      state    develop    power   sector       meet     take
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  1000  Alpha:  0.5  Eta:  0.5
#        Topic_0    Topic_1    Topic_2  Topic_3  Topic_4    Topic_5  Topic_6
# 0        state       rise      water  develop      per      trump  develop
# 1       report    weather       food     work     cent         us   nation
# 2       carbon      flood  scientist     need  develop  agreement  project
# 3         plan      level        use    china    water     nation     time
# 4       nation       time   research     risk   nation      china     fund
# 5        water  scientist     school      uae    state      state  support
# 6        trump      storm     nation     make     risk     accord     need
# 7       impact       make       time       us     area     leader   africa
# 8  environment      human      state   nation  million    develop    first
# 9       action      state    develop    power   region       meet     take
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  3000  Alpha:  0.001  Eta:  0.001
#    Topic_0    Topic_1  Topic_2 Topic_3  Topic_4   Topic_5   Topic_6
# 0   nation      trump    india   trump    water     water   develop
# 1      per         us       us    time  project     state   nigeria
# 2    china      state    power  nation  develop    impact    nation
# 3     cent  agreement   nation    warm     plan      food     china
# 4  develop     carbon  develop   state      use    farmer     state
# 5     need     accord     time   human     area  research   support
# 6     food       warm    state      us  sustain   weather   sustain
# 7      use        gas   action  report   nation    forest      work
# 8    state       risk    china    make     need    report      need
# 9  nigeria     invest      uae   storm    state      make  nigerian
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  3000  Alpha:  0.001  Eta:  0.1
#    Topic_0    Topic_1  Topic_2 Topic_3  Topic_4   Topic_5   Topic_6
# 0   nation      trump    india   trump    water     water   develop
# 1      per         us       us    time  project     state   nigeria
# 2    china      state    power  nation  develop    impact    nation
# 3     cent  agreement   nation    warm     plan      food     china
# 4  develop     carbon  develop   state      use    farmer     state
# 5     need     accord     time   human     area  research   support
# 6     food       warm    state      us  sustain   weather   sustain
# 7      use        gas   action  report   nation    forest      work
# 8    state       risk    china    make     need    report      need
# 9   report     invest   report   storm    state      make  nigerian
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  3000  Alpha:  0.001  Eta:  0.5
#    Topic_0    Topic_1  Topic_2 Topic_3  Topic_4   Topic_5   Topic_6
# 0   nation      trump    india   trump    water     water   develop
# 1      per         us       us    time  project     state   nigeria
# 2    china      state    power  nation  develop    impact    nation
# 3     cent  agreement   nation    warm     plan      food     china
# 4  develop     carbon    state   state      use    farmer     state
# 5     need     accord     time      us     area   weather   support
# 6     food       warm  develop   human  sustain  research   sustain
# 7      use        gas   action  report   nation    report      work
# 8    state       risk    china    make     need    forest      need
# 9   report     invest   carbon   storm    state      make  nigerian
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  3000  Alpha:  0.1  Eta:  0.001
#    Topic_0    Topic_1  Topic_2 Topic_3  Topic_4      Topic_5   Topic_6
# 0   nation      trump    india   trump    water        water   develop
# 1      per         us       us    time  project        state   nigeria
# 2    china      state    power  nation  develop       impact    nation
# 3     cent  agreement   nation    warm     plan      weather     china
# 4  develop     carbon  develop   state      use     research     state
# 5     need     accord     time      us     area       farmer   support
# 6     food       warm    state   human  sustain         food   sustain
# 7      use        gas   action  report   nation       forest      work
# 8    state     invest      uae    make     need       report      need
# 9   report       risk    china   storm    plant  environment  nigerian
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  3000  Alpha:  0.1  Eta:  0.1
#    Topic_0    Topic_1  Topic_2 Topic_3  Topic_4   Topic_5   Topic_6
# 0   nation      trump    india   trump    water     water   develop
# 1      per         us       us    time  project     state   nigeria
# 2    china      state    power  nation  develop    impact    nation
# 3     cent  agreement   nation    warm     plan   weather     china
# 4  develop     carbon  develop   state      use  research     state
# 5     need     accord     time      us     area      food   support
# 6     food       warm    state   human  sustain    farmer   sustain
# 7      use        gas   action  report   nation    forest      work
# 8    state     invest    china    make     need    report      need
# 9   report       risk      uae   storm    plant      make  nigerian
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  3000  Alpha:  0.1  Eta:  0.5
#    Topic_0    Topic_1  Topic_2 Topic_3  Topic_4   Topic_5   Topic_6
# 0   nation      trump    india   trump    water     water   develop
# 1      per         us       us    time  project     state   nigeria
# 2    china      state    power  nation  develop    impact    nation
# 3     cent  agreement   nation    warm     plan      food     china
# 4  develop     carbon     time   state      use   weather     state
# 5     need     accord    state      us     area  research   support
# 6     food       warm  develop   human  sustain    farmer   sustain
# 7      use        gas   action  report   nation    report      work
# 8   report     invest    china    make     need    forest      need
# 9    state       risk   carbon   storm    plant      make  nigerian
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  3000  Alpha:  0.5  Eta:  0.001
#    Topic_0    Topic_1  Topic_2 Topic_3  Topic_4      Topic_5   Topic_6
# 0   nation      trump       us  nation    water        water   develop
# 1      per         us    india   trump  project        state   nigeria
# 2    china      state    power    time  develop       impact    nation
# 3     food  agreement   nation    warm      use      weather     china
# 4     need     carbon     time   state     plan     research     state
# 5  develop     accord  develop      us     area       farmer   support
# 6     cent       warm    state   human   nation         make   sustain
# 7      use        gas      uae  report  sustain  environment      work
# 8    state     invest   action    make     need         food      need
# 9   report       risk     work   storm    state       forest  nigerian
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  3000  Alpha:  0.5  Eta:  0.1
#    Topic_0    Topic_1  Topic_2 Topic_3    Topic_4      Topic_5   Topic_6
# 0   nation      trump       us  nation      water        water   develop
# 1      per         us    india   trump    project        state   nigeria
# 2    china      state    power    time    develop       impact    nation
# 3     food  agreement   nation    warm        use      weather     china
# 4     need     carbon     time   state       plan     research     state
# 5  develop     accord  develop      us       area       farmer   support
# 6     cent       warm   action   human     nation         make   sustain
# 7      use        gas    state  report    sustain         food      work
# 8    state     invest     work    make       need  environment      need
# 9   report       risk      uae   storm  agreement       forest  nigerian
#
# Norm:  _stem Num topics:  7 , Max df:  0.5  Max features:  3000  Alpha:  0.5  Eta:  0.5
#    Topic_0    Topic_1  Topic_2 Topic_3  Topic_4      Topic_5   Topic_6
# 0   nation      trump       us  nation    water        water   develop
# 1      per         us    india   trump  project        state   nigeria
# 2    china      state    power    time  develop       impact    nation
# 3     food  agreement   nation    warm      use      weather     china
# 4     need     carbon     time   state     plan     research     state
# 5  develop     accord   action      us     area       farmer   support
# 6     cent       warm  develop   human   nation         make   sustain
# 7      use        gas    state  report  sustain         food      work
# 8   report     invest     work    make     need  environment      need
# 9    state       risk   carbon   storm    state       forest  nigerian

# %%
num_topics = [3,4]
max_dfs = [0.5]
max_features = [1000, 3000]
norm_type = [ '_stem']

alphas = [0.1]
etas = [0.1]

stop_words = lucem_illud.stop_words_basic +  ['climat', 'chang', 'like', 'year','mr', 'say','could']

# %%
topic_loop(news_df, stop_words, num_topics, max_dfs, max_features, norm_type, alphas, etas, random_number=1024)
# Out:
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  1000  Alpha:  0.1  Eta:  0.1
#      Topic_0    Topic_1  Topic_2
# 0      trump       time  develop
# 1      state       make    china
# 2         us  scientist   nation
# 3     nation       rise     food
# 4  agreement      human  nigeria
# 5     report         us     need
# 6     accord      level    water
# 7       plan    weather   region
# 8    develop      state     work
# 9       need     nation      use
#
# Norm:  _stem Num topics:  3 , Max df:  0.5  Max features:  3000  Alpha:  0.1  Eta:  0.1
#    Topic_0    Topic_1   Topic_2
# 0   nation      trump        us
# 1  develop         us   develop
# 2    state      state    nation
# 3    water       warm      time
# 4     need  agreement      work
# 5  nigeria     carbon     state
# 6      use       make     india
# 7     food  scientist    report
# 8     make       time  research
# 9  sustain     report    action
#
# Norm:  _stem Num topics:  4 , Max df:  0.5  Max features:  1000  Alpha:  0.1  Eta:  0.1
#      Topic_0    Topic_1   Topic_2  Topic_3
# 0      trump       time   develop  develop
# 1      state       rise     water    china
# 2         us       make      food       us
# 3     nation  scientist    nation     work
# 4  agreement      human   nigeria     need
# 5     report    weather  research   nation
# 6     accord      level       use    trump
# 7       plan        per     china     make
# 8     carbon      flood    region    power
# 9     action         us     state     risk
#
# Norm:  _stem Num topics:  4 , Max df:  0.5  Max features:  3000  Alpha:  0.1  Eta:  0.1
#    Topic_0    Topic_1    Topic_2      Topic_3
# 0  develop      trump    develop        trump
# 1   nation         us         us        state
# 2    water      state      india       nation
# 3    state  agreement     nation         time
# 4  nigeria       warm       work           us
# 5     need     carbon      state        human
# 6  sustain       risk      power         warm
# 7     food        gas      china       report
# 8      use     invest       time         make
# 9    china     accord  agreement  environment
