# %% [markdown]
# # Comparing the climate change news article production across countries in the sample.
# For analysis, please refer to the article

# %%
import pandas
import gensim
import matplotlib
import sklearn
import sklearn.metrics
import seaborn
import scipy
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
news_df = pandas.concat([pandas.read_pickle('../news_df_norm1.pkl'), pandas.read_pickle('../news_df_norm2.pkl')])

# %%
news_df.head(5)
# Out:
#                author country                date                   filename  \
# 0  Stephanie Peatling      AU       March 9, 2017  ./data/AU/AU7.2 (40).html
# 1        Peter Hannam      AU   December 10, 2017      ./data/AU/AUS_74.html
# 2        Peter Hannam      AU   December 10, 2017      ./data/AU/AUS_75.html
# 3        Peter Hannam      AU  September 12, 2017    ./data/AU/AU8_9_68.html
# 4        Crispin Hull      AU  September 30, 2017      ./data/AU/AU6_65.html
#
#   section                                             source  \
# 0    News            Sydney Morning Herald, The (Australia)
# 1    News                   Canberra Times, The (Australia)
# 2   Extra               Sun Herald, The (Sydney, Australia)
# 3    News  Age, The/The Sunday Age (Melbourne, Australia)...
# 4   Forum                   Canberra Times, The (Australia)
#
#                                                 text  \
# 0  Scientists have confirmed what anyone who live...
# ...

# %% [markdown]
# Tagging each article with its unique filename and country, in order to be able to calculate similarities using them.
# <br> Constructing the Doc2Vec model

# %%
news_df['gensim_tagged_doc'] = news_df.apply(lambda x: gensim.models.doc2vec.TaggedDocument(
    x.normalized_tokens, [x.filename, x.country]), axis=1)

# %%
d2v_model = gensim.models.doc2vec.Doc2Vec(news_df['gensim_tagged_doc'], size=1000, workers=4)

# %% [markdown]
# <br> <br> First, similarities across countries-as-documents

# %%
heatmapMatrix = []
countries = news_df.country.unique()
for tagOuter in countries:
    column = []
    tagVec = d2v_model.docvecs[tagOuter].reshape(1, -1)
    for tagInner in countries:
        column.append(sklearn.metrics.pairwise.cosine_similarity(tagVec, d2v_model.docvecs[tagInner].reshape(1, -1))[0][0])
    heatmapMatrix.append(column)
heatmapMatrix = np.array(heatmapMatrix)
fig, ax = plt.subplots(figsize=(15,10))
hmap = ax.pcolor(heatmapMatrix, cmap='viridis')
cbar = plt.colorbar(hmap)

cbar.set_label('cosine similarity', rotation=270)
a = ax.set_xticks(np.arange(heatmapMatrix.shape[1]) + 0.5, minor=False)
a = ax.set_yticks(np.arange(heatmapMatrix.shape[0]) + 0.5, minor=False)

a = ax.set_xticklabels(countries, minor=False, rotation=270)
a = ax.set_yticklabels(countries, minor=False)

plt.xlabel('Country label')
plt.title('Label similarity')
plt.ylabel('Country label')
# Out:
# Text(0,0.5,'Country label')

# %% [markdown]
# <br> <br> <br> To assess and address variance within each country, we get each country's document's vectors and compare across all of them to all of them, obtaining the mean per each country to each country, and assessing its significance

# %%
def get_vecs_for_country(country_tag):
    holder = []
    for ix, row in news_df[news_df['country']==country_tag].iterrows():
        holder.append(d2v_model.docvecs[row['filename']])
    return np.array(holder)

# %%
means = np.zeros((8,8))
means_significance = np.full((8, 8), False)
test_power = 0.05

for ix, country in enumerate(news_df.country.unique()):
    for jx, country2 in enumerate(news_df.country.unique()):
        means[ix,jx] = sklearn.metrics.pairwise.cosine_similarity(get_vecs_for_country(country), 
                                                                  get_vecs_for_country(country2)).mean()
        testres = scipy.stats.ttest_1samp(sklearn.metrics.pairwise.cosine_similarity(get_vecs_for_country(country), 
                                                                  get_vecs_for_country(country2)).flatten(), 0)
        means_significance[ix,jx] =  testres[1] > test_power  #Mask does NOT show when True, so we need the opposite of what we want

# %%
fig, ax = plt.subplots(figsize=(15,10))
plt.title('Mean document similarity')
ax = sns.heatmap(means,xticklabels=countries, yticklabels=countries, ax=ax, cmap='viridis', mask=means_significance, annot=True)

# %%
# Test for significance used above
for ix, country in enumerate(news_df.country.unique()):
    for jx, country2 in enumerate(news_df.country.unique()):
        testres = scipy.stats.ttest_1samp(sklearn.metrics.pairwise.cosine_similarity(get_vecs_for_country(country), 
                                                                  get_vecs_for_country(country2)).flatten(), 0)
        print("{} {} significant? {} ".format(country, country2, testres[1]<0.05))
# Out:
# AU AU significant? True
# AU CH significant? False
# AU IN significant? True
# AU KE significant? False
# AU ME significant? True
# AU NG significant? True
# AU UK significant? False
# AU US significant? False
# CH AU significant? False
# CH CH significant? True
# CH IN significant? False
# CH KE significant? False
# CH ME significant? False
# CH NG significant? False
# CH UK significant? True
# CH US significant? False
# IN AU significant? True
# IN CH significant? False
# IN IN significant? True
# IN KE significant? True
# IN ME significant? True
# IN NG significant? True
# IN UK significant? True
# IN US significant? True
# KE AU significant? False
# KE CH significant? False
# KE IN significant? True
# KE KE significant? True
# KE ME significant? True
# KE NG significant? True
# KE UK significant? False
# KE US significant? True
# ME AU significant? True
# ME CH significant? False
# ME IN significant? True
# ME KE significant? True
# ME ME significant? True
# ...

# %%
# Making sure the p-value is being filtered correctly
scipy.stats.ttest_1samp(sklearn.metrics.pairwise.cosine_similarity(get_vecs_for_country('US'), 
                                                                  get_vecs_for_country('US')).flatten(),0)[1]
# Out:
# 1.1905838198320665e-12

# %% [markdown]
# <br> Obtaining the same country-as-document similarity as the first one, but this time using seaborn to get annotations

# %%
import scipy
#sklearn.metrics.pairwise.cosine_similarity(get_vecs_for_country('NG'), get_vecs_for_country('KE')).var()
comps = np.zeros((8,8))
#means_significance = np.full((8, 8), False)
#test_power = 0.05

for ix, country in enumerate(news_df.country.unique()):
    for jx, country2 in enumerate(news_df.country.unique()):
        comps[ix,jx] = sklearn.metrics.pairwise.cosine_similarity(d2v_model.docvecs[country].reshape(1,-1),
                                                                  d2v_model.docvecs[country2].reshape(1,-1))[0,0]

import seaborn as sns
fig, ax = plt.subplots(figsize=(15,10))
plt.title('Country-as-document similarity')
ax = sns.heatmap(comps,xticklabels=countries, yticklabels=countries, ax=ax, cmap='viridis', annot=True)

# %% [markdown]
# <br> <br>
# #### Trying other statistics - left  out

# %%
medians = np.zeros((8,8))
for ix, country in enumerate(news_df.country.unique()):
    for jx, country2 in enumerate(news_df.country.unique()):
        medians[ix,jx] = np.median(sklearn.metrics.pairwise.cosine_similarity(get_vecs_for_country(country), 
                                                                  get_vecs_for_country(country2)))
import seaborn as sns
fig, ax = plt.subplots(figsize=(15,10))
plt.title('Mean document similarity')
ax = sns.heatmap(medians,xticklabels=countries, yticklabels=countries, ax=ax, cmap='viridis')

# %%
variances = np.zeros((1,8))
for ix, country in enumerate(news_df.country.unique()):
    variances[0,ix] = sklearn.metrics.pairwise.cosine_similarity(get_vecs_for_country(country), 
                                                                  get_vecs_for_country(country)).var()

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(8,2))
plt.title('Country similarity variance')
ax = sns.heatmap(variances, xticklabels=countries, yticklabels=['self'])
